# %% [markdown]
# **1. What are the advantages of a CNN for image classification over a completely linked DNN?**
#
# Convolutional Neural Networks (CNNs) have several advantages over fully connected Deep Neural Networks (DNNs) for image classification:
#
# - **Parameter Sharing**: A feature detector (like a kernel or filter) in CNNs learns a specific feature and can be applied across the entire image. This drastically reduces the number of parameters, making the model more efficient and less prone to overfitting.
#
# - **Spatial Hierarchies**: CNNs inherently recognize spatial hierarchies in data. Lower layers might detect edges, while deeper layers might detect more complex structures. This hierarchical feature extraction isn't present in regular DNNs.
#
# - **Translation Invariance**: Once a CNN learns a feature in one part of an image, it can recognize it in any other part. This property is extremely beneficial for image data.
#
# - **Reduced Computational Needs**: Due to pooling and shared parameters, CNNs often require fewer computational resources than DNNs for equivalent tasks.
#
# - **Better Handling of Image Data**: CNNs handle varying image sizes better than DNNs, which require a fixed input size.

# %% [markdown]
# **2. Consider a CNN with three convolutional layers, each of which has three kernels, a stride of two, and SAME padding. The bottom layer generates 100 feature maps, the middle layer 200, and the top layer 400. RGB images with a size of 200 x 300 pixels are used as input. How many parameters does the CNN have in total? How much RAM would this network need when making a single instance prediction if we're using 32-bit floats? What if you were to practice on a batch of 50 images?**
#
# Given:
# - CNN with three convolutional layers.
# - Each convolutional layer has three kernels.
# - Stride of two and SAME padding for each layer.
# - 1st layer (bottom layer) generates 100 feature maps.
# - 2nd layer (middle layer) generates 200 feature maps.
# - 3rd layer (top layer) generates 400 feature maps.
# - Input: RGB images of size 200 x 300 pixels.
#
# Steps:
# 1. Calculate the number of parameters for each layer.
# 2. Compute the total number of parameters.
# 3. Compute the RAM required for a single instance prediction using 32-bit floats.
# 4. Calculate the RAM required for a batch of 50 images.

# %%
# Given values
filter_width = 3
filter_height = 3
input_channels_layer1 = 3 # RGB channels
num_filters_layer1 = 100
num_filters_layer2 = 200
num_filters_layer3 = 400

# Calculate parameters for each layer
params_layer1 = (filter_width * filter_height * input_channels_layer1 + 1) * num_filters_layer1
params_layer2 = (filter_width * filter_height * num_filters_layer1 + 1) * num_filters_layer2
params_layer3 = (filter_width * filter_height * num_filters_layer2 + 1) * num_filters_layer3

# Total parameters
total_params = params_layer1 + params_layer2 + params_layer3

# RAM for a single instance prediction (32-bit floats, 4 bytes each)
ram_single_instance = total_params * 4  # in bytes

# RAM for a batch of 50 images
ram_batch_50 = ram_single_instance * 50  # in bytes

total_params, ram_single_instance, ram_batch_50
# Out:
# (903400, 3613600, 180680000)

# %% [markdown]
# **2. Results for the given CNN architecture:**
#
# - **Total Parameters**: 903,400
# - **RAM required for a single instance prediction (using 32-bit floats)**: 3,613,600 bytes (or approximately 3.61 MB)
# - **RAM required for a batch of 50 images**: 180,680,000 bytes (or approximately 180.68 MB)

# %% [markdown]
# **3. What are five things you might do to fix the problem if your GPU runs out of memory while training a CNN?**
#
# - **Reduce Batch Size**: One of the most straightforward methods to reduce GPU memory consumption is to decrease the batch size.
#
# - **Gradient Accumulation**: Instead of updating weights after every small batch, gradients are accumulated over multiple small batches and updated less frequently.
#
# - **Model Pruning**: This involves removing neurons or entire layers that contribute little to the final prediction, reducing the model's size.
#
# - **Use Checkpoints**: Save model weights periodically and clear GPU memory, then resume training from the last checkpoint.
#
# - **Model Quantization**: This process reduces the precision of the model's parameters, which can save memory without significant loss in performance.
#
# **4. Why would you use a max pooling layer instead of a convolutional layer with the same stride?**
#
# Max pooling layers are used to downsample the spatial dimensions of the input, reducing the computational burden and number of parameters. Advantages include:
#
# - **Parameter Reduction**: Unlike convolutional layers, max pooling doesn't introduce new parameters.
#
# - **Translation Invariance**: Max pooling can make the model more robust to slight translations or distortions in the input.
#
# - **Reduction in Spatial Dimensions**: This can help to focus on the most important features in the input data.
#
# **5. When would a local response normalization layer be useful?**
#
# Local Response Normalization (LRN) layers were once popular in the early days of CNNs. They normalize neuron activities in a way that promotes lateral inhibition, emphasizing some activation over others. They can be useful:
#
# - When trying to make the activations of a neuron relative to its neighboring neurons.
# - In scenarios where the model is overfitting, as normalization can introduce a form of regularization.
#
# However, it's worth noting that LRN has become less popular with the advent of Batch Normalization, which normalizes neuron activities across batches and has proven to be more effective in many cases.
#
# **6. In comparison to LeNet-5, what are the main innovations in AlexNet? What about GoogLeNet and ResNet's core innovations?**
#
# - **AlexNet**:
#   - Deeper architecture with more layers.
#   - Use of ReLU activation function for faster training.
#   - Implementation of dropout layers for regularization.
#   - GPU implementation to handle the increased computational demand.
#
# - **GoogLeNet**:
#   - Introduction of the "Inception" module, which allows the network to choose between various convolutional kernel sizes and pooling operations.
#   - Use of 1x1 convolutions to reduce the number of parameters.
#   - No use of fully connected layers, thus reducing parameters.
#
# - **ResNet**:
#   - Introduction of "skip connections" or "residual connections" to allow gradients to flow through the network, mitigating the vanishing gradient problem in deep networks.
#   - Ability to train extremely deep networks (e.g., ResNet-152) by leveraging these residual connections.
#
# **7. On MNIST, build your own CNN and strive to achieve the best possible accuracy.**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

# 1. Load and preprocess the MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# 2. Define the CNN architecture
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# 3. Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 4. Train the model
model.fit(train_images, train_labels, epochs=10, batch_size=64, validation_split=0.2)

# 5. Evaluate the model
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
# Epoch 1/10
# 750/750 [==============================] - 31s 38ms/step - loss: 0.2128 - accuracy: 0.9362 - val_loss: 0.0721 - val_accuracy: 0.9778
# Epoch 2/10
# 750/750 [==============================] - 29s 38ms/step - loss: 0.0567 - accuracy: 0.9825 - val_loss: 0.0499 - val_accuracy: 0.9850
# Epoch 3/10
# 750/750 [==============================] - 29s 38ms/step - loss: 0.0405 - accuracy: 0.9874 - val_loss: 0.0522 - val_accuracy: 0.9849
# Epoch 4/10
# 750/750 [==============================] - 28s 38ms/step - loss: 0.0300 - accuracy: 0.9901 - val_loss: 0.0540 - val_accuracy: 0.9845
# Epoch 5/10
# 750/750 [==============================] - 29s 38ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.0402 - val_accuracy: 0.9885
# Epoch 6/10
# 750/750 [==============================] - 27s 37ms/step - loss: 0.0187 - accuracy: 0.9940 - val_loss: 0.0450 - val_accuracy: 0.9877
# Epoch 7/10
# 750/750 [==============================] - 28s 37ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 0.0400 - val_accuracy: 0.9885
# Epoch 8/10
# 750/750 [==============================] - 28s 37ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.0511 - val_accuracy: 0.9877
# Epoch 9/10
# 750/750 [==============================] - 28s 37ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0425 - val_accuracy: 0.9895
# Epoch 10/10
# 750/750 [==============================] - 28s 37ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0410 - val_accuracy: 0.9898
# 313/313 [==============================] - 3s 10ms/step - loss: 0.0301 - accuracy: 0.9911
# Test accuracy: 0.991100013256073

# %% [markdown]
# **8. Using Inception v3 to classify broad images...**
#
# - Images of different animals can be downloaded.
# - Load them in Python using the matplotlib.image.mpimg.imread() or scipy.misc.imread() functions, for example.
# - Resize and/or crop them to 299 x 299 pixels, and make sure they only have three channels (RGB) and no transparency.
# - The photos used to train the Inception model were preprocessed to have values ranging from -1.0 to 1.0, so make sure yours do as well.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np

# 1. Load the CIFAR-10 dataset
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

# 2. Extract animal images (e.g., cats, which are class index 3 in CIFAR-10)
animal_class_index = 3
animal_images = [img for img, label in tfds.as_numpy(ds_train) if label == animal_class_index]

# 3. Resize and preprocess these images for Inception v3 (which expects 299x299 images)
animal_images_resized = [tf.image.resize(img, [299, 299]) for img in animal_images]
animal_images_processed = [preprocess_input(img) for img in animal_images_resized]

# 4. Use the Inception v3 model for classification
model = InceptionV3(weights='imagenet')

predictions = model.predict(np.array(animal_images_processed))
decoded_predictions = decode_predictions(predictions, top=3)  # Directly pass the batched predictions

# Print the top 3 predictions for each image
for i, pred in enumerate(decoded_predictions):
    print(f"Image {i + 1}:")
    for imagenet_id, label, score in pred:
        print(f"{label} ({score:.2f})")
# Out:
# 157/157 [==============================] - 171s 1s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 [==============================] - 0s 1us/step
# Image 1:
# marmoset (0.34)
# Windsor_tie (0.15)
# fox_squirrel (0.02)
# Image 2:
# lotion (0.39)
# nipple (0.12)
# whiskey_jug (0.08)
# Image 3:
# tabby (0.30)
# Egyptian_cat (0.15)
# tiger_cat (0.11)
# Image 4:
# red_wolf (0.17)
# lesser_panda (0.11)
# kit_fox (0.11)
# Image 5:
# Japanese_spaniel (0.24)
# Border_collie (0.05)
# EntleBucher (0.03)
# Image 6:
# web_site (0.23)
# screen (0.22)
# book_jacket (0.07)
# Image 7:
# nipple (0.22)
# redbone (0.19)
# golden_retriever (0.07)
# Image 8:
# Persian_cat (0.99)
# tabby (0.00)
# tiger_cat (0.00)
# Image 9:
# Persian_cat (0.30)
# milk_can (0.21)
# Brabancon_griffon (0.04)
# Image 10:
# cougar (0.98)
# jaguar (0.00)
# lion (0.00)
# Image 11:
# schipperke (0.31)
# ocarina (0.08)
# curly-coated_retriever (0.08)
# Image 12:
# milk_can (0.07)
# Persian_cat (0.04)
# Madagascar_cat (0.03)
# Image 13:
# chiffonier (0.24)
# pool_table (0.20)
# desk (0.08)
# Image 14:
# whiskey_jug (0.14)
# lotion (0.13)
# nipple (0.05)
# Image 15:
# Japanese_spaniel (0.44)
# Blenheim_spaniel (0.16)
# Persian_cat (0.06)
# Image 16:
# Persian_cat (0.22)
# eggnog (0.13)
# marmoset (0.12)
# Image 17:
# tabby (0.17)
# Persian_cat (0.11)
# tiger_cat (0.05)
# Image 18:
# throne (0.10)
# cradle (0.08)
# thresher (0.08)
# Image 19:
# Persian_cat (0.83)
# bearskin (0.02)
# tiger_cat (0.01)
# Image 20:
# EntleBucher (0.15)
# Greater_Swiss_Mountain_dog (0.07)
# Japanese_spaniel (0.04)
# Image 21:
# Madagascar_cat (0.15)
# Eskimo_dog (0.07)
# indri (0.05)
# Image 22:
# polecat (0.23)
# EntleBucher (0.05)
# black-and-tan_coonhound (0.03)
# Image 23:
# Kerry_blue_terrier (0.27)
# toy_terrier (0.11)
# affenpinscher (0.05)
# Image 24:
# lotion (0.37)
# moving_van (0.10)
# punching_bag (0.07)
# Image 25:
# Arctic_fox (0.29)
# Persian_cat (0.09)
# Eskimo_dog (0.05)
# Image 26:
# black_grouse (0.46)
# curly-coated_retriever (0.03)
# waffle_iron (0.02)
# Image 27:
# rotisserie (0.36)
# bearskin (0.13)
# screen (0.05)
# Image 28:
# Windsor_tie (0.03)
# velvet (0.03)
# bolo_tie (0.03)
# Image 29:
# Windsor_tie (0.44)
# can_opener (0.16)
# milk_can (0.07)
# Image 30:
# lotion (0.22)
# milk_can (0.06)
# can_opener (0.05)
# Image 31:
# indri (0.24)
# Madagascar_cat (0.22)
# keeshond (0.13)
# Image 32:
# platypus (0.24)
# redbone (0.14)
# hyena (0.08)
# Image 33:
# tabby (0.28)
# Egyptian_cat (0.17)
# tiger_cat (0.10)
# Image 34:
# polecat (0.33)
# weasel (0.09)
# marmoset (0.05)
# Image 35:
# Sealyham_terrier (0.10)
# Japanese_spaniel (0.08)
# affenpinscher (0.04)
# Image 36:
# hourglass (0.12)
# bobsled (0.06)
# Windsor_tie (0.04)
# Image 37:
# EntleBucher (0.32)
# Border_collie (0.10)
# Greater_Swiss_Mountain_dog (0.04)
# Image 38:
# cradle (0.19)
# pedestal (0.09)
# nipple (0.07)
# Image 39:
# can_opener (0.19)
# hourglass (0.17)
# guillotine (0.10)
# Image 40:
# kit_fox (0.13)
# Windsor_tie (0.08)
# Persian_cat (0.04)
# Image 41:
# tabby (0.31)
# Persian_cat (0.30)
# Egyptian_cat (0.22)
# Image 42:
# lynx (0.25)
# Persian_cat (0.12)
# kit_fox (0.09)
# Image 43:
# isopod (0.17)
# platypus (0.07)
# whistle (0.04)
# Image 44:
# Windsor_tie (0.34)
# gong (0.23)
# rock_beauty (0.05)
# Image 45:
# clog (0.04)
# fox_squirrel (0.04)
# tiger_cat (0.03)
# Image 46:
# polecat (0.27)
# weasel (0.26)
# mink (0.04)
# Image 47:
# basenji (0.38)
# Pembroke (0.16)
# English_foxhound (0.04)
# Image 48:
# moving_van (0.23)
# lotion (0.17)
# book_jacket (0.14)
# Image 49:
# milk_can (0.13)
# bulletproof_vest (0.09)
# muzzle (0.08)
# Image 50:
# potter's_wheel (0.11)
# waffle_iron (0.07)
# isopod (0.05)
# Image 51:
# plate_rack (0.44)
# rotisserie (0.33)
# fire_screen (0.03)
# Image 52:
# plate_rack (0.91)
# Japanese_spaniel (0.01)
# gong (0.01)
# Image 53:
# colobus (0.16)
# chain_saw (0.09)
# Siamese_cat (0.04)
# Image 54:
# tiger_cat (0.40)
# tabby (0.36)
# Egyptian_cat (0.03)
# Image 55:
# fox_squirrel (0.25)
# polecat (0.06)
# weasel (0.05)
# Image 56:
# African_hunting_dog (0.43)
# kit_fox (0.23)
# hyena (0.06)
# Image 57:
# tabby (0.82)
# tiger_cat (0.12)
# Egyptian_cat (0.02)
# Image 58:
# marmoset (0.16)
# otterhound (0.12)
# Sussex_spaniel (0.08)
# Image 59:
# black-and-tan_coonhound (0.15)
# sorrel (0.09)
# hartebeest (0.08)
# Image 60:
# Japanese_spaniel (0.27)
# king_penguin (0.16)
# red-breasted_merganser (0.04)
# Image 61:
# Walker_hound (0.14)
# English_foxhound (0.09)
# patas (0.08)
# Image 62:
# Brabancon_griffon (0.15)
# basenji (0.10)
# dhole (0.08)
# Image 63:
# redbone (0.50)
# Walker_hound (0.06)
# English_foxhound (0.05)
# Image 64:
# Madagascar_cat (0.53)
# indri (0.11)
# fox_squirrel (0.03)
# Image 65:
# Japanese_spaniel (0.15)
# Persian_cat (0.06)
# Walker_hound (0.06)
# Image 66:
# Arctic_fox (0.56)
# kit_fox (0.14)
# Persian_cat (0.04)
# Image 67:
# screen (0.06)
# oil_filter (0.03)
# tiger_cat (0.03)
# Image 68:
# thresher (0.13)
# revolver (0.08)
# binder (0.06)
# Image 69:
# bulletproof_vest (0.25)
# affenpinscher (0.06)
# curly-coated_retriever (0.04)
# Image 70:
# indri (0.17)
# Madagascar_cat (0.16)
# English_foxhound (0.03)
# Image 71:
# banded_gecko (0.10)
# fox_squirrel (0.05)
# brambling (0.04)
# Image 72:
# Persian_cat (0.31)
# affenpinscher (0.18)
# Sussex_spaniel (0.11)
# Image 73:
# tabby (0.61)
# tiger_cat (0.10)
# Egyptian_cat (0.07)
# Image 74:
# quilt (0.32)
# Persian_cat (0.08)
# studio_couch (0.02)
# Image 75:
# kit_fox (0.10)
# brown_bear (0.09)
# Chihuahua (0.04)
# Image 76:
# Persian_cat (0.10)
# tiger_cat (0.08)
# milk_can (0.06)
# Image 77:
# kit_fox (0.13)
# fox_squirrel (0.13)
# wallaby (0.09)
# Image 78:
# muzzle (0.15)
# Egyptian_cat (0.09)
# Brabancon_griffon (0.05)
# Image 79:
# Egyptian_cat (0.47)
# tiger_cat (0.24)
# tabby (0.09)
# Image 80:
# whiskey_jug (0.29)
# frilled_lizard (0.17)
# tabby (0.07)
# Image 81:
# ocarina (0.37)
# rock_beauty (0.12)
# green_mamba (0.06)
# Image 82:
# fox_squirrel (0.15)
# tabby (0.07)
# polecat (0.04)
# Image 83:
# golden_retriever (0.40)
# lion (0.07)
# dishwasher (0.06)
# Image 84:
# chain_saw (0.66)
# whiskey_jug (0.02)
# Crock_Pot (0.01)
# Image 85:
# bearskin (0.43)
# overskirt (0.12)
# velvet (0.05)
# Image 86:
# barrel (0.12)
# milk_can (0.11)
# chain_saw (0.06)
# Image 87:
# Persian_cat (0.17)
# ant (0.14)
# Dandie_Dinmont (0.08)
# Image 88:
# kit_fox (0.11)
# English_foxhound (0.05)
# red_fox (0.04)
# Image 89:
# triceratops (0.65)
# kit_fox (0.04)
# coyote (0.04)
# Image 90:
# Border_collie (0.18)
# toy_terrier (0.15)
# EntleBucher (0.08)
# Image 91:
# nipple (0.23)
# plate_rack (0.12)
# spatula (0.10)
# Image 92:
# moving_van (0.09)
# thresher (0.08)
# espresso_maker (0.06)
# Image 93:
# patas (0.23)
# squirrel_monkey (0.10)
# langur (0.10)
# Image 94:
# Cardigan (0.06)
# macaque (0.04)
# dingo (0.04)
# Image 95:
# black-and-tan_coonhound (0.03)
# maraca (0.03)
# lighter (0.02)
# Image 96:
# coyote (0.44)
# grey_fox (0.12)
# kit_fox (0.09)
# Image 97:
# nipple (0.12)
# Windsor_tie (0.03)
# chiffonier (0.03)
# Image 98:
# tiger_cat (0.08)
# Madagascar_cat (0.07)
# bluetick (0.07)
# Image 99:
# punching_bag (0.03)
# thresher (0.03)
# affenpinscher (0.02)
# Image 100:
# chain_saw (0.23)
# guillotine (0.15)
# ocarina (0.02)
# Image 101:
# tiger_cat (0.31)
# Persian_cat (0.17)
# tabby (0.14)
# Image 102:
# Egyptian_cat (0.15)
# tabby (0.12)
# lynx (0.07)
# Image 103:
# panpipe (0.12)
# muzzle (0.11)
# milk_can (0.05)
# Image 104:
# shoji (0.15)
# clog (0.11)
# panpipe (0.09)
# Image 105:
# Egyptian_cat (0.61)
# tabby (0.13)
# tiger_cat (0.08)
# Image 106:
# Siamese_cat (0.44)
# Egyptian_cat (0.10)
# wallaby (0.07)
# Image 107:
# Japanese_spaniel (0.34)
# Saint_Bernard (0.07)
# Blenheim_spaniel (0.05)
# Image 108:
# clog (0.26)
# hourglass (0.05)
# golden_retriever (0.03)
# Image 109:
# Japanese_spaniel (0.31)
# siamang (0.26)
# colobus (0.04)
# Image 110:
# tiger_cat (0.41)
# tabby (0.13)
# Egyptian_cat (0.08)
# Image 111:
# Pembroke (0.22)
# Cardigan (0.14)
# basenji (0.13)
# Image 112:
# panpipe (0.25)
# bassoon (0.16)
# oboe (0.03)
# Image 113:
# Walker_hound (0.05)
# Japanese_spaniel (0.05)
# bluetick (0.05)
# Image 114:
# bolo_tie (0.35)
# maraca (0.10)
# can_opener (0.10)
# Image 115:
# bearskin (0.23)
# marmoset (0.07)
# Japanese_spaniel (0.04)
# Image 116:
# platypus (0.50)
# spotted_salamander (0.09)
# chain_saw (0.06)
# Image 117:
# Persian_cat (0.10)
# chow (0.07)
# Bouvier_des_Flandres (0.06)
# Image 118:
# kit_fox (0.19)
# red_wolf (0.04)
# Persian_cat (0.03)
# Image 119:
# velvet (0.18)
# earthstar (0.06)
# hen-of-the-woods (0.05)
# Image 120:
# can_opener (0.14)
# plunger (0.07)
# whiskey_jug (0.05)
# Image 121:
# hatchet (0.04)
# plunger (0.03)
# Japanese_spaniel (0.03)
# Image 122:
# Persian_cat (0.24)
# tabby (0.11)
# screen (0.11)
# Image 123:
# triceratops (0.10)
# Walker_hound (0.05)
# English_foxhound (0.05)
# Image 124:
# black-and-tan_coonhound (0.10)
# bluetick (0.07)
# rock_python (0.06)
# Image 125:
# rock_python (0.84)
# frilled_lizard (0.01)
# Sussex_spaniel (0.01)
# Image 126:
# toy_terrier (0.70)
# fox_squirrel (0.09)
# Windsor_tie (0.02)
# Image 127:
# pedestal (0.26)
# nipple (0.13)
# ice_bear (0.05)
# Image 128:
# Persian_cat (0.98)
# Japanese_spaniel (0.00)
# pirate (0.00)
# Image 129:
# Japanese_spaniel (0.22)
# Persian_cat (0.18)
# affenpinscher (0.12)
# Image 130:
# kit_fox (0.31)
# grey_fox (0.23)
# red_fox (0.09)
# Image 131:
# Mexican_hairless (0.26)
# redbone (0.10)
# lion (0.05)
# Image 132:
# Siamese_cat (0.65)
# toy_terrier (0.02)
# Japanese_spaniel (0.01)
# Image 133:
# muzzle (0.22)
# sorrel (0.08)
# fox_squirrel (0.03)
# Image 134:
# milk_can (0.22)
# espresso_maker (0.10)
# moving_van (0.09)
# Image 135:
# Japanese_spaniel (0.48)
# Blenheim_spaniel (0.08)
# papillon (0.02)
# Image 136:
# toy_terrier (0.27)
# basenji (0.11)
# wire-haired_fox_terrier (0.10)
# Image 137:
# Japanese_spaniel (0.06)
# Walker_hound (0.04)
# English_foxhound (0.03)
# Image 138:
# patas (0.42)
# Madagascar_cat (0.08)
# squirrel_monkey (0.04)
# Image 139:
# bolo_tie (0.07)
# maraca (0.06)
# can_opener (0.04)
# Image 140:
# Windsor_tie (0.22)
# safe (0.06)
# can_opener (0.04)
# Image 141:
# English_foxhound (0.35)
# Japanese_spaniel (0.16)
# wire-haired_fox_terrier (0.08)
# Image 142:
# goldfish (0.11)
# Windsor_tie (0.09)
# velvet (0.08)
# Image 143:
# timber_wolf (0.25)
# coyote (0.12)
# dhole (0.11)
# Image 144:
# triceratops (0.97)
# tabby (0.01)
# Egyptian_cat (0.00)
# Image 145:
# affenpinscher (0.09)
# bulletproof_vest (0.04)
# Irish_water_spaniel (0.04)
# Image 146:
# Sussex_spaniel (0.05)
# hen-of-the-woods (0.03)
# black_grouse (0.03)
# Image 147:
# book_jacket (0.34)
# oil_filter (0.10)
# packet (0.08)
# Image 148:
# coyote (0.60)
# kit_fox (0.06)
# grey_fox (0.03)
# Image 149:
# lynx (0.16)
# tiger_cat (0.11)
# dhole (0.04)
# Image 150:
# ant (0.27)
# hatchet (0.19)
# Walker_hound (0.07)
# Image 151:
# chain_saw (0.43)
# tabby (0.10)
# can_opener (0.10)
# Image 152:
# fox_squirrel (0.54)
# wood_rabbit (0.06)
# lynx (0.02)
# Image 153:
# tiger_cat (0.19)
# tabby (0.16)
# lynx (0.09)
# Image 154:
# eggnog (0.05)
# plate (0.03)
# bell_pepper (0.03)
# Image 155:
# red_fox (0.18)
# Pembroke (0.11)
# dhole (0.06)
# Image 156:
# fox_squirrel (0.17)
# marmoset (0.07)
# patas (0.06)
# Image 157:
# Persian_cat (0.96)
# Siamese_cat (0.00)
# Japanese_spaniel (0.00)
# Image 158:
# Egyptian_cat (0.08)
# indri (0.08)
# doormat (0.07)
# Image 159:
# screen (0.32)
# rotisserie (0.18)
# corn (0.13)
# Image 160:
# tiger (0.57)
# fox_squirrel (0.08)
# tiger_cat (0.02)
# Image 161:
# tabby (0.50)
# tiger_cat (0.20)
# Egyptian_cat (0.19)
# Image 162:
# Japanese_spaniel (0.38)
# book_jacket (0.04)
# wire-haired_fox_terrier (0.04)
# Image 163:
# tabby (0.40)
# Egyptian_cat (0.23)
# tiger_cat (0.10)
# Image 164:
# tabby (0.64)
# tiger_cat (0.06)
# Egyptian_cat (0.05)
# Image 165:
# moving_van (0.13)
# screen (0.10)
# milk_can (0.04)
# Image 166:
# Japanese_spaniel (0.14)
# Persian_cat (0.10)
# papillon (0.09)
# Image 167:
# revolver (0.42)
# can_opener (0.06)
# Japanese_spaniel (0.03)
# Image 168:
# lynx (0.14)
# fox_squirrel (0.14)
# Egyptian_cat (0.12)
# Image 169:
# Windsor_tie (0.05)
# muzzle (0.04)
# hourglass (0.02)
# Image 170:
# snow_leopard (0.10)
# coyote (0.07)
# kit_fox (0.06)
# Image 171:
# triceratops (0.07)
# pinwheel (0.05)
# redbone (0.04)
# Image 172:
# cradle (0.43)
# Loafer (0.35)
# plane (0.10)
# Image 173:
# Japanese_spaniel (0.12)
# Madagascar_cat (0.04)
# pick (0.03)
# Image 174:
# screen (0.08)
# panpipe (0.05)
# milk_can (0.05)
# Image 175:
# parallel_bars (0.18)
# screen (0.15)
# balance_beam (0.05)
# Image 176:
# nipple (0.14)
# conch (0.11)
# table_lamp (0.06)
# Image 177:
# redbone (0.27)
# Brabancon_griffon (0.06)
# nipple (0.03)
# Image 178:
# marmoset (0.79)
# patas (0.03)
# Persian_cat (0.02)
# Image 179:
# hourglass (0.08)
# dining_table (0.06)
# table_lamp (0.05)
# Image 180:
# stopwatch (0.06)
# Windsor_tie (0.05)
# bolo_tie (0.04)
# Image 181:
# leopard (0.39)
# Egyptian_cat (0.11)
# tiger_cat (0.07)
# Image 182:
# hourglass (0.47)
# EntleBucher (0.12)
# bluetick (0.09)
# Image 183:
# English_foxhound (0.12)
# clog (0.07)
# colobus (0.07)
# Image 184:
# redbone (0.37)
# triceratops (0.07)
# dhole (0.05)
# Image 185:
# thresher (0.19)
# Sussex_spaniel (0.06)
# black-and-tan_coonhound (0.06)
# Image 186:
# whiskey_jug (0.10)
# Windsor_tie (0.06)
# clog (0.04)
# Image 187:
# Egyptian_cat (0.20)
# Persian_cat (0.06)
# kit_fox (0.06)
# Image 188:
# espresso_maker (0.46)
# milk_can (0.07)
# hourglass (0.07)
# Image 189:
# entertainment_center (0.28)
# microwave (0.18)
# television (0.07)
# Image 190:
# triceratops (0.32)
# milk_can (0.15)
# gong (0.04)
# Image 191:
# yellow_lady's_slipper (0.29)
# fig (0.22)
# maraca (0.09)
# Image 192:
# gong (0.08)
# pick (0.08)
# ocarina (0.04)
# Image 193:
# siamang (0.47)
# spider_monkey (0.11)
# colobus (0.07)
# Image 194:
# Eskimo_dog (0.27)
# coyote (0.12)
# malamute (0.07)
# Image 195:
# Walker_hound (0.10)
# whiskey_jug (0.07)
# English_foxhound (0.06)
# Image 196:
# bolo_tie (0.10)
# Windsor_tie (0.07)
# tick (0.05)
# Image 197:
# Walker_hound (0.45)
# English_foxhound (0.08)
# bluetick (0.08)
# Image 198:
# chain_saw (0.02)
# panpipe (0.02)
# fox_squirrel (0.02)
# Image 199:
# Egyptian_cat (0.34)
# tabby (0.19)
# Persian_cat (0.12)
# Image 200:
# Madagascar_cat (0.07)
# Windsor_tie (0.06)
# Persian_cat (0.06)
# Image 201:
# lotion (0.07)
# whiskey_jug (0.04)
# sunscreen (0.04)
# Image 202:
# Persian_cat (0.44)
# Brabancon_griffon (0.06)
# kit_fox (0.04)
# Image 203:
# eggnog (0.28)
# milk_can (0.21)
# hot_pot (0.08)
# Image 204:
# Windsor_tie (0.27)
# nipple (0.04)
# loupe (0.03)
# Image 205:
# oxcart (0.17)
# Japanese_spaniel (0.06)
# amphibian (0.05)
# Image 206:
# chain_saw (0.37)
# Dandie_Dinmont (0.04)
# fox_squirrel (0.04)
# Image 207:
# Persian_cat (0.49)
# milk_can (0.11)
# eggnog (0.08)
# Image 208:
# Arctic_fox (0.27)
# Madagascar_cat (0.12)
# Egyptian_cat (0.07)
# Image 209:
# screen (0.06)
# dugong (0.05)
# loupe (0.04)
# Image 210:
# Windsor_tie (0.06)
# Brabancon_griffon (0.03)
# abaya (0.03)
# Image 211:
# moving_van (0.05)
# sorrel (0.05)
# patas (0.04)
# Image 212:
# Japanese_spaniel (0.10)
# Persian_cat (0.06)
# Eskimo_dog (0.05)
# Image 213:
# squirrel_monkey (0.15)
# Madagascar_cat (0.08)
# wood_rabbit (0.07)
# Image 214:
# milk_can (0.26)
# amphibian (0.07)
# dishwasher (0.06)
# Image 215:
# dhole (0.13)
# red_wolf (0.08)
# coyote (0.07)
# Image 216:
# nipple (0.15)
# whiskey_jug (0.12)
# ice_bear (0.11)
# Image 217:
# espresso_maker (0.19)
# plate_rack (0.12)
# whiskey_jug (0.10)
# Image 218:
# panpipe (0.79)
# guillotine (0.02)
# English_foxhound (0.01)
# Image 219:
# velvet (0.15)
# chambered_nautilus (0.13)
# hen-of-the-woods (0.06)
# Image 220:
# Persian_cat (0.10)
# desktop_computer (0.04)
# Japanese_spaniel (0.04)
# Image 221:
# moving_van (0.58)
# balance_beam (0.05)
# dishwasher (0.03)
# Image 222:
# chain_saw (0.17)
# clog (0.08)
# English_foxhound (0.03)
# Image 223:
# Japanese_spaniel (0.62)
# EntleBucher (0.04)
# Persian_cat (0.03)
# Image 224:
# rock_beauty (0.08)
# fox_squirrel (0.07)
# broccoli (0.04)
# Image 225:
# Japanese_spaniel (0.77)
# EntleBucher (0.04)
# Walker_hound (0.03)
# Image 226:
# black-and-tan_coonhound (0.36)
# can_opener (0.22)
# EntleBucher (0.04)
# Image 227:
# tabby (0.35)
# lynx (0.23)
# tiger_cat (0.20)
# Image 228:
# moving_van (0.33)
# book_jacket (0.18)
# shoji (0.06)
# Image 229:
# plane (0.28)
# Madagascar_cat (0.03)
# Egyptian_cat (0.03)
# Image 230:
# Madagascar_cat (0.70)
# platypus (0.03)
# English_foxhound (0.02)
# Image 231:
# Band_Aid (0.13)
# cassette (0.12)
# book_jacket (0.09)
# Image 232:
# bobsled (0.54)
# chain_saw (0.19)
# amphibian (0.04)
# Image 233:
# milk_can (0.17)
# whiskey_jug (0.09)
# eggnog (0.04)
# Image 234:
# Windsor_tie (0.68)
# sweatshirt (0.02)
# vestment (0.02)
# Image 235:
# tabby (0.21)
# toy_terrier (0.10)
# Cardigan (0.07)
# Image 236:
# chain_saw (0.28)
# jersey (0.18)
# football_helmet (0.07)
# Image 237:
# pick (0.12)
# bobsled (0.07)
# whiskey_jug (0.05)
# Image 238:
# Japanese_spaniel (0.81)
# papillon (0.03)
# indri (0.02)
# Image 239:
# pedestal (0.56)
# bulletproof_vest (0.07)
# barrel (0.05)
# Image 240:
# hyena (0.17)
# lion (0.12)
# brown_bear (0.05)
# Image 241:
# moving_van (0.08)
# dishwasher (0.05)
# tobacco_shop (0.05)
# Image 242:
# Japanese_spaniel (0.18)
# milk_can (0.07)
# muzzle (0.04)
# Image 243:
# capuchin (0.28)
# marmoset (0.26)
# patas (0.08)
# Image 244:
# Persian_cat (0.29)
# polecat (0.15)
# Madagascar_cat (0.10)
# Image 245:
# bolo_tie (0.38)
# maraca (0.15)
# pick (0.11)
# Image 246:
# colobus (0.22)
# indri (0.10)
# gibbon (0.06)
# Image 247:
# bearskin (0.16)
# snow_leopard (0.07)
# comic_book (0.06)
# Image 248:
# bearskin (0.30)
# book_jacket (0.05)
# Windsor_tie (0.04)
# Image 249:
# fox_squirrel (0.16)
# lynx (0.07)
# coyote (0.05)
# Image 250:
# can_opener (0.09)
# lotion (0.09)
# nipple (0.07)
# Image 251:
# tiger_cat (0.62)
# tabby (0.22)
# Egyptian_cat (0.12)
# Image 252:
# whiskey_jug (0.21)
# milk_can (0.12)
# can_opener (0.06)
# Image 253:
# milk_can (0.41)
# whiskey_jug (0.10)
# punching_bag (0.06)
# Image 254:
# goldfish (0.88)
# rock_beauty (0.02)
# sorrel (0.00)
# Image 255:
# kit_fox (0.21)
# Egyptian_cat (0.13)
# cheetah (0.09)
# Image 256:
# chambered_nautilus (0.38)
# ocarina (0.04)
# colobus (0.03)
# Image 257:
# kit_fox (0.12)
# grey_fox (0.12)
# coyote (0.10)
# Image 258:
# siamang (0.22)
# Windsor_tie (0.08)
# indri (0.07)
# Image 259:
# patas (0.07)
# lion (0.06)
# lynx (0.05)
# Image 260:
# Japanese_spaniel (0.76)
# toy_terrier (0.01)
# Persian_cat (0.01)
# Image 261:
# EntleBucher (0.63)
# Walker_hound (0.07)
# Japanese_spaniel (0.05)
# Image 262:
# black-and-tan_coonhound (0.29)
# bluetick (0.20)
# EntleBucher (0.12)
# Image 263:
# chimpanzee (0.11)
# EntleBucher (0.08)
# muzzle (0.04)
# Image 264:
# bearskin (0.41)
# chimpanzee (0.18)
# siamang (0.06)
# Image 265:
# fox_squirrel (0.24)
# mousetrap (0.06)
# mongoose (0.04)
# Image 266:
# lotion (0.72)
# hair_spray (0.12)
# cocktail_shaker (0.05)
# Image 267:
# fox_squirrel (0.51)
# Persian_cat (0.10)
# marmoset (0.06)
# Image 268:
# Mexican_hairless (0.28)
# toy_terrier (0.12)
# Great_Dane (0.07)
# Image 269:
# polecat (0.21)
# Persian_cat (0.18)
# marmoset (0.06)
# Image 270:
# tiger_cat (0.36)
# tabby (0.30)
# Egyptian_cat (0.17)
# Image 271:
# milk_can (0.08)
# Walker_hound (0.07)
# fox_squirrel (0.06)
# Image 272:
# patas (0.42)
# Madagascar_cat (0.12)
# English_foxhound (0.05)
# Image 273:
# oil_filter (0.26)
# thresher (0.11)
# triceratops (0.06)
# Image 274:
# hourglass (0.74)
# guillotine (0.08)
# pedestal (0.01)
# Image 275:
# Japanese_spaniel (0.22)
# Kerry_blue_terrier (0.08)
# affenpinscher (0.07)
# Image 276:
# tiger_cat (0.34)
# Egyptian_cat (0.29)
# tabby (0.27)
# Image 277:
# hourglass (0.26)
# table_lamp (0.17)
# pool_table (0.05)
# Image 278:
# sorrel (0.24)
# basenji (0.18)
# Walker_hound (0.07)
# Image 279:
# Madagascar_cat (0.20)
# colobus (0.08)
# sloth_bear (0.07)
# Image 280:
# airliner (0.08)
# plane (0.06)
# screen (0.05)
# Image 281:
# wire-haired_fox_terrier (0.18)
# German_short-haired_pointer (0.16)
# English_foxhound (0.11)
# Image 282:
# langur (0.21)
# colobus (0.15)
# Madagascar_cat (0.07)
# Image 283:
# Egyptian_cat (0.38)
# tabby (0.04)
# moving_van (0.04)
# Image 284:
# orangutan (0.05)
# Sussex_spaniel (0.04)
# Windsor_tie (0.04)
# Image 285:
# milk_can (0.15)
# jersey (0.13)
# hatchet (0.08)
# Image 286:
# can_opener (0.23)
# milk_can (0.12)
# punching_bag (0.09)
# Image 287:
# patas (0.13)
# Japanese_spaniel (0.08)
# king_penguin (0.04)
# Image 288:
# book_jacket (0.18)
# Band_Aid (0.12)
# lotion (0.11)
# Image 289:
# milk_can (0.39)
# fox_squirrel (0.04)
# platypus (0.02)
# Image 290:
# spotlight (0.18)
# whiskey_jug (0.11)
# gong (0.08)
# Image 291:
# whiskey_jug (0.30)
# Windsor_tie (0.10)
# overskirt (0.03)
# Image 292:
# hatchet (0.43)
# Japanese_spaniel (0.06)
# bolo_tie (0.02)
# Image 293:
# Mexican_hairless (0.46)
# groenendael (0.11)
# Great_Dane (0.09)
# Image 294:
# tabby (0.50)
# Egyptian_cat (0.08)
# tiger_cat (0.06)
# Image 295:
# sidewinder (0.41)
# rock_python (0.19)
# horned_viper (0.03)
# Image 296:
# marmoset (0.11)
# Madagascar_cat (0.10)
# patas (0.09)
# Image 297:
# lynx (0.21)
# tabby (0.17)
# cheetah (0.07)
# Image 298:
# fox_squirrel (0.10)
# Mexican_hairless (0.05)
# toy_terrier (0.05)
# Image 299:
# Egyptian_cat (0.68)
# toy_terrier (0.05)
# basenji (0.05)
# Image 300:
# Egyptian_cat (0.12)
# polecat (0.08)
# Siamese_cat (0.07)
# Image 301:
# maraca (0.06)
# nail (0.04)
# Cardigan (0.04)
# Image 302:
# Japanese_spaniel (0.05)
# Persian_cat (0.04)
# black-and-tan_coonhound (0.03)
# Image 303:
# Persian_cat (0.26)
# fox_squirrel (0.23)
# theater_curtain (0.03)
# Image 304:
# magnetic_compass (0.04)
# Brabancon_griffon (0.03)
# schipperke (0.03)
# Image 305:
# fox_squirrel (0.35)
# squirrel_monkey (0.06)
# triceratops (0.04)
# Image 306:
# kit_fox (0.08)
# Arctic_fox (0.05)
# red_fox (0.05)
# Image 307:
# fox_squirrel (0.47)
# squirrel_monkey (0.05)
# marmoset (0.03)
# Image 308:
# tabby (0.31)
# Egyptian_cat (0.16)
# tiger_cat (0.15)
# Image 309:
# can_opener (0.39)
# Petri_dish (0.03)
# consomme (0.02)
# Image 310:
# whistle (0.08)
# can_opener (0.07)
# waffle_iron (0.05)
# Image 311:
# Sealyham_terrier (0.37)
# wire-haired_fox_terrier (0.09)
# overskirt (0.08)
# Image 312:
# lotion (0.14)
# Persian_cat (0.14)
# Brabancon_griffon (0.06)
# Image 313:
# wood_rabbit (0.46)
# fox_squirrel (0.33)
# hare (0.04)
# Image 314:
# Walker_hound (0.33)
# wire-haired_fox_terrier (0.09)
# Siamese_cat (0.07)
# Image 315:
# analog_clock (0.07)
# siamang (0.06)
# pick (0.05)
# Image 316:
# EntleBucher (0.27)
# Cardigan (0.16)
# Bernese_mountain_dog (0.07)
# Image 317:
# screen (0.23)
# hand-held_computer (0.08)
# rotisserie (0.07)
# Image 318:
# eggnog (0.82)
# nipple (0.03)
# Petri_dish (0.03)
# Image 319:
# lion (0.32)
# cheetah (0.10)
# tiger (0.08)
# Image 320:
# tabby (0.44)
# tiger_cat (0.10)
# malamute (0.09)
# Image 321:
# face_powder (0.15)
# consomme (0.09)
# Crock_Pot (0.06)
# Image 322:
# curly-coated_retriever (0.34)
# affenpinscher (0.08)
# black_grouse (0.04)
# Image 323:
# fox_squirrel (0.39)
# wood_rabbit (0.33)
# hare (0.03)
# Image 324:
# indri (0.32)
# Japanese_spaniel (0.13)
# Madagascar_cat (0.04)
# Image 325:
# bobsled (0.14)
# fox_squirrel (0.06)
# black-and-tan_coonhound (0.04)
# Image 326:
# tabby (0.16)
# Siamese_cat (0.08)
# Persian_cat (0.07)
# Image 327:
# Japanese_spaniel (0.10)
# toy_terrier (0.07)
# triceratops (0.06)
# Image 328:
# lynx (0.35)
# tiger_cat (0.26)
# Egyptian_cat (0.06)
# Image 329:
# Eskimo_dog (0.10)
# muzzle (0.09)
# dingo (0.08)
# Image 330:
# tabby (0.89)
# tiger_cat (0.02)
# Egyptian_cat (0.01)
# Image 331:
# Madagascar_cat (0.23)
# fox_squirrel (0.09)
# tabby (0.06)
# Image 332:
# neck_brace (0.43)
# pick (0.23)
# ocarina (0.02)
# Image 333:
# Brabancon_griffon (0.36)
# Persian_cat (0.15)
# spider_monkey (0.04)
# Image 334:
# Siamese_cat (0.93)
# Egyptian_cat (0.00)
# milk_can (0.00)
# Image 335:
# Egyptian_cat (0.59)
# tabby (0.07)
# standard_schnauzer (0.03)
# Image 336:
# pinwheel (0.20)
# wall_clock (0.12)
# matchstick (0.09)
# Image 337:
# German_short-haired_pointer (0.15)
# muzzle (0.07)
# bluetick (0.05)
# Image 338:
# Egyptian_cat (0.37)
# fox_squirrel (0.10)
# Persian_cat (0.09)
# Image 339:
# Mexican_hairless (0.33)
# toy_terrier (0.21)
# punching_bag (0.04)
# Image 340:
# Madagascar_cat (0.69)
# indri (0.18)
# can_opener (0.01)
# Image 341:
# carton (0.07)
# screen (0.06)
# Kerry_blue_terrier (0.04)
# Image 342:
# triceratops (0.39)
# Sussex_spaniel (0.03)
# affenpinscher (0.03)
# Image 343:
# Madagascar_cat (0.12)
# bearskin (0.11)
# siamang (0.08)
# Image 344:
# Persian_cat (0.29)
# patas (0.10)
# lion (0.10)
# Image 345:
# Chihuahua (0.09)
# toy_terrier (0.04)
# French_bulldog (0.03)
# Image 346:
# Egyptian_cat (0.26)
# fox_squirrel (0.18)
# tabby (0.16)
# Image 347:
# Japanese_spaniel (0.52)
# Walker_hound (0.02)
# Brabancon_griffon (0.02)
# Image 348:
# American_black_bear (0.14)
# colobus (0.08)
# howler_monkey (0.06)
# Image 349:
# nipple (0.04)
# platypus (0.04)
# jacamar (0.04)
# Image 350:
# Dandie_Dinmont (0.33)
# wire-haired_fox_terrier (0.05)
# fox_squirrel (0.03)
# Image 351:
# coyote (0.08)
# Ibizan_hound (0.06)
# grey_fox (0.06)
# Image 352:
# Siamese_cat (0.11)
# Egyptian_cat (0.07)
# plastic_bag (0.04)
# Image 353:
# Japanese_spaniel (0.21)
# Pomeranian (0.19)
# Persian_cat (0.11)
# Image 354:
# wire-haired_fox_terrier (0.34)
# Japanese_spaniel (0.13)
# Walker_hound (0.05)
# Image 355:
# German_shepherd (0.40)
# kelpie (0.08)
# muzzle (0.07)
# Image 356:
# affenpinscher (0.29)
# Kerry_blue_terrier (0.19)
# Brabancon_griffon (0.08)
# Image 357:
# dishwasher (0.10)
# guillotine (0.05)
# tobacco_shop (0.04)
# Image 358:
# bearskin (0.99)
# bobsled (0.00)
# puck (0.00)
# Image 359:
# entertainment_center (0.93)
# television (0.00)
# screen (0.00)
# Image 360:
# ocarina (0.43)
# rock_beauty (0.17)
# goldfish (0.03)
# Image 361:
# Italian_greyhound (0.20)
# German_short-haired_pointer (0.09)
# toy_terrier (0.07)
# Image 362:
# toy_terrier (0.08)
# wire-haired_fox_terrier (0.07)
# Blenheim_spaniel (0.07)
# Image 363:
# chain_saw (0.35)
# motor_scooter (0.10)
# power_drill (0.09)
# Image 364:
# toy_terrier (0.39)
# papillon (0.18)
# Madagascar_cat (0.03)
# Image 365:
# Japanese_spaniel (0.14)
# indri (0.12)
# Persian_cat (0.04)
# Image 366:
# screen (0.25)
# laptop (0.05)
# coyote (0.04)
# Image 367:
# Chihuahua (0.17)
# Mexican_hairless (0.09)
# French_bulldog (0.05)
# Image 368:
# velvet (0.20)
# skunk (0.05)
# Japanese_spaniel (0.04)
# Image 369:
# Japanese_spaniel (0.87)
# papillon (0.02)
# Windsor_tie (0.01)
# Image 370:
# Arctic_fox (0.30)
# kit_fox (0.04)
# Norwegian_elkhound (0.03)
# Image 371:
# moving_van (0.15)
# carton (0.06)
# oil_filter (0.04)
# Image 372:
# waffle_iron (0.28)
# potter's_wheel (0.05)
# Brabancon_griffon (0.03)
# Image 373:
# pick (0.68)
# rock_beauty (0.02)
# bobsled (0.01)
# Image 374:
# Japanese_spaniel (0.45)
# Persian_cat (0.06)
# wire-haired_fox_terrier (0.03)
# Image 375:
# weasel (0.06)
# polecat (0.05)
# velvet (0.04)
# Image 376:
# brambling (0.10)
# clog (0.05)
# maraca (0.03)
# Image 377:
# sloth_bear (0.11)
# guenon (0.08)
# colobus (0.05)
# Image 378:
# basenji (0.41)
# EntleBucher (0.07)
# toy_terrier (0.06)
# Image 379:
# indri (0.30)
# Madagascar_cat (0.22)
# bobsled (0.05)
# Image 380:
# Siamese_cat (0.94)
# Mexican_hairless (0.02)
# Egyptian_cat (0.00)
# Image 381:
# fox_squirrel (0.10)
# patas (0.07)
# muzzle (0.04)
# Image 382:
# lynx (0.24)
# Egyptian_cat (0.14)
# tabby (0.11)
# Image 383:
# Brabancon_griffon (0.08)
# patas (0.07)
# muzzle (0.03)
# Image 384:
# barn_spider (0.11)
# triceratops (0.10)
# bluetick (0.07)
# Image 385:
# tabby (0.62)
# tiger_cat (0.14)
# Egyptian_cat (0.11)
# Image 386:
# pick (0.24)
# bolo_tie (0.16)
# jersey (0.04)
# Image 387:
# bulletproof_vest (0.25)
# fire_screen (0.10)
# amphibian (0.06)
# Image 388:
# Siamese_cat (0.66)
# Persian_cat (0.05)
# langur (0.03)
# Image 389:
# keeshond (0.81)
# Persian_cat (0.02)
# schipperke (0.01)
# Image 390:
# panpipe (0.99)
# maraca (0.00)
# hatchet (0.00)
# Image 391:
# can_opener (0.04)
# reel (0.04)
# cocktail_shaker (0.04)
# Image 392:
# mink (0.11)
# curly-coated_retriever (0.10)
# German_short-haired_pointer (0.07)
# Image 393:
# basenji (0.14)
# tiger_cat (0.08)
# muzzle (0.03)
# Image 394:
# chambered_nautilus (0.07)
# overskirt (0.05)
# cradle (0.05)
# Image 395:
# fox_squirrel (0.10)
# wire-haired_fox_terrier (0.08)
# bearskin (0.06)
# Image 396:
# bulletproof_vest (0.16)
# potter's_wheel (0.09)
# neck_brace (0.05)
# Image 397:
# Japanese_spaniel (0.36)
# papillon (0.07)
# Blenheim_spaniel (0.04)
# Image 398:
# Pomeranian (0.12)
# Japanese_spaniel (0.10)
# Sealyham_terrier (0.08)
# Image 399:
# wallaby (0.10)
# Egyptian_cat (0.08)
# tiger_cat (0.08)
# Image 400:
# polecat (0.30)
# lesser_panda (0.21)
# platypus (0.20)
# Image 401:
# indri (0.13)
# earthstar (0.09)
# black_stork (0.06)
# Image 402:
# sloth_bear (0.19)
# fire_screen (0.18)
# matchstick (0.02)
# Image 403:
# eggnog (0.14)
# toy_terrier (0.04)
# English_foxhound (0.03)
# Image 404:
# fire_screen (0.28)
# croquet_ball (0.11)
# safety_pin (0.09)
# Image 405:
# Bedlington_terrier (0.13)
# malamute (0.10)
# timber_wolf (0.06)
# Image 406:
# Persian_cat (0.11)
# marmoset (0.05)
# whiskey_jug (0.03)
# Image 407:
# studio_couch (0.06)
# mousetrap (0.03)
# table_lamp (0.03)
# Image 408:
# screen (0.84)
# Persian_cat (0.12)
# desktop_computer (0.01)
# Image 409:
# basenji (0.42)
# English_foxhound (0.12)
# Italian_greyhound (0.05)
# Image 410:
# Madagascar_cat (0.42)
# fox_squirrel (0.17)
# grey_fox (0.09)
# Image 411:
# German_short-haired_pointer (0.14)
# redbone (0.10)
# black-and-tan_coonhound (0.10)
# Image 412:
# whiskey_jug (0.11)
# fox_squirrel (0.06)
# magnetic_compass (0.05)
# Image 413:
# gazelle (0.18)
# kit_fox (0.07)
# fox_squirrel (0.05)
# Image 414:
# moving_van (0.09)
# nipple (0.08)
# goldfish (0.07)
# Image 415:
# Walker_hound (0.44)
# bluetick (0.07)
# black-and-tan_coonhound (0.06)
# Image 416:
# Mexican_hairless (0.55)
# eel (0.04)
# Egyptian_cat (0.03)
# Image 417:
# coyote (0.13)
# Irish_water_spaniel (0.07)
# black-and-tan_coonhound (0.05)
# Image 418:
# espresso_maker (0.96)
# can_opener (0.01)
# espresso (0.00)
# Image 419:
# bulletproof_vest (0.31)
# dogsled (0.27)
# amphibian (0.11)
# Image 420:
# can_opener (0.07)
# waffle_iron (0.04)
# plate_rack (0.04)
# Image 421:
# Windsor_tie (0.55)
# bolo_tie (0.03)
# marmoset (0.02)
# Image 422:
# milk_can (0.20)
# whiskey_jug (0.16)
# pill_bottle (0.12)
# Image 423:
# Persian_cat (0.40)
# Siamese_cat (0.10)
# marmoset (0.07)
# Image 424:
# croquet_ball (0.31)
# cleaver (0.05)
# maraca (0.05)
# Image 425:
# lynx (0.61)
# leopard (0.07)
# Persian_cat (0.05)
# Image 426:
# thimble (0.12)
# soap_dispenser (0.07)
# nipple (0.07)
# Image 427:
# Japanese_spaniel (0.08)
# kit_fox (0.07)
# EntleBucher (0.06)
# Image 428:
# Windsor_tie (0.14)
# colobus (0.09)
# Japanese_spaniel (0.08)
# Image 429:
# Egyptian_cat (0.36)
# tabby (0.34)
# tiger_cat (0.08)
# Image 430:
# Egyptian_cat (0.10)
# Siamese_cat (0.08)
# marmoset (0.06)
# Image 431:
# fox_squirrel (0.34)
# Persian_cat (0.09)
# Brabancon_griffon (0.05)
# Image 432:
# milk_can (0.54)
# lesser_panda (0.06)
# polecat (0.04)
# Image 433:
# tiger_cat (0.39)
# tabby (0.19)
# lynx (0.15)
# Image 434:
# waffle_iron (0.11)
# spatula (0.10)
# chiton (0.10)
# Image 435:
# tiger_cat (0.34)
# lynx (0.17)
# tabby (0.06)
# Image 436:
# EntleBucher (0.46)
# Japanese_spaniel (0.20)
# Madagascar_cat (0.04)
# Image 437:
# rock_python (0.13)
# whiskey_jug (0.11)
# ocarina (0.08)
# Image 438:
# Siamese_cat (0.18)
# Arctic_fox (0.11)
# clog (0.07)
# Image 439:
# EntleBucher (0.42)
# bluetick (0.26)
# Walker_hound (0.08)
# Image 440:
# lesser_panda (0.23)
# Madagascar_cat (0.09)
# brown_bear (0.07)
# Image 441:
# space_bar (0.04)
# can_opener (0.03)
# Norwegian_elkhound (0.03)
# Image 442:
# toy_terrier (0.21)
# lotion (0.12)
# English_foxhound (0.06)
# Image 443:
# Madagascar_cat (0.45)
# langur (0.06)
# Japanese_spaniel (0.03)
# Image 444:
# clog (0.23)
# book_jacket (0.16)
# milk_can (0.14)
# Image 445:
# Brabancon_griffon (0.14)
# rotisserie (0.14)
# golden_retriever (0.13)
# Image 446:
# schipperke (0.18)
# skunk (0.04)
# curly-coated_retriever (0.03)
# Image 447:
# lynx (0.14)
# tabby (0.11)
# tiger_cat (0.08)
# Image 448:
# punching_bag (0.27)
# hourglass (0.27)
# milk_can (0.06)
# Image 449:
# kit_fox (0.41)
# red_fox (0.12)
# dingo (0.08)
# Image 450:
# hourglass (0.22)
# nipple (0.15)
# espresso_maker (0.08)
# Image 451:
# head_cabbage (0.22)
# polecat (0.05)
# tiger_cat (0.05)
# Image 452:
# nipple (0.13)
# Japanese_spaniel (0.05)
# Windsor_tie (0.04)
# Image 453:
# nipple (0.70)
# Brabancon_griffon (0.05)
# redbone (0.05)
# Image 454:
# EntleBucher (0.86)
# Walker_hound (0.03)
# Greater_Swiss_Mountain_dog (0.01)
# Image 455:
# shoji (0.42)
# balance_beam (0.09)
# yawl (0.05)
# Image 456:
# skunk (0.17)
# brown_bear (0.07)
# lesser_panda (0.04)
# Image 457:
# indri (0.49)
# Madagascar_cat (0.03)
# langur (0.01)
# Image 458:
# packet (0.27)
# moving_van (0.24)
# book_jacket (0.15)
# Image 459:
# tabby (0.39)
# Egyptian_cat (0.33)
# tiger_cat (0.14)
# Image 460:
# chain_saw (0.30)
# rotisserie (0.03)
# fox_squirrel (0.03)
# Image 461:
# tabby (0.27)
# panpipe (0.21)
# tiger_cat (0.18)
# Image 462:
# EntleBucher (0.22)
# gibbon (0.07)
# English_foxhound (0.06)
# Image 463:
# fox_squirrel (0.23)
# triceratops (0.11)
# Dandie_Dinmont (0.04)
# Image 464:
# bluetick (0.16)
# siamang (0.16)
# colobus (0.08)
# Image 465:
# tabby (0.10)
# marmoset (0.06)
# Persian_cat (0.05)
# Image 466:
# nipple (0.61)
# pick (0.32)
# Windsor_tie (0.00)
# Image 467:
# bearskin (0.23)
# banded_gecko (0.15)
# pickelhaube (0.03)
# Image 468:
# Persian_cat (0.97)
# Japanese_spaniel (0.00)
# milk_can (0.00)
# Image 469:
# Sussex_spaniel (0.39)
# Brabancon_griffon (0.06)
# golden_retriever (0.02)
# Image 470:
# kit_fox (0.20)
# African_hunting_dog (0.10)
# Madagascar_cat (0.06)
# Image 471:
# fox_squirrel (0.34)
# coyote (0.04)
# timber_wolf (0.04)
# Image 472:
# fox_squirrel (0.09)
# Persian_cat (0.07)
# Madagascar_cat (0.05)
# Image 473:
# theater_curtain (0.12)
# hourglass (0.07)
# otterhound (0.05)
# Image 474:
# Japanese_spaniel (0.12)
# loupe (0.06)
# nipple (0.05)
# Image 475:
# hog (0.11)
# Mexican_hairless (0.06)
# langur (0.03)
# Image 476:
# sorrel (0.81)
# Indian_elephant (0.02)
# oxcart (0.01)
# Image 477:
# pick (0.95)
# bolo_tie (0.01)
# consomme (0.00)
# Image 478:
# Windsor_tie (0.25)
# nipple (0.18)
# cradle (0.08)
# Image 479:
# lion (0.20)
# wire-haired_fox_terrier (0.10)
# hyena (0.07)
# Image 480:
# Australian_terrier (0.14)
# Norwich_terrier (0.09)
# sorrel (0.04)
# Image 481:
# sorrel (0.54)
# thresher (0.22)
# redbone (0.02)
# Image 482:
# nipple (0.57)
# lotion (0.10)
# whiskey_jug (0.06)
# Image 483:
# red-breasted_merganser (0.69)
# milk_can (0.03)
# English_foxhound (0.02)
# Image 484:
# Sussex_spaniel (0.48)
# lion (0.11)
# tiger_cat (0.06)
# Image 485:
# milk_can (0.24)
# shoji (0.15)
# guillotine (0.04)
# Image 486:
# Windsor_tie (0.35)
# Siamese_cat (0.04)
# Walker_hound (0.04)
# Image 487:
# Siamese_cat (0.20)
# Madagascar_cat (0.17)
# Persian_cat (0.11)
# Image 488:
# chambered_nautilus (0.94)
# tick (0.00)
# rock_python (0.00)
# Image 489:
# Brabancon_griffon (0.15)
# golden_retriever (0.14)
# Irish_setter (0.06)
# Image 490:
# EntleBucher (0.09)
# black-and-tan_coonhound (0.07)
# Walker_hound (0.04)
# Image 491:
# patas (0.21)
# frilled_lizard (0.04)
# toy_terrier (0.04)
# Image 492:
# plane (0.23)
# can_opener (0.08)
# iron (0.08)
# Image 493:
# red-breasted_merganser (0.30)
# speedboat (0.12)
# otter (0.04)
# Image 494:
# Arctic_fox (0.26)
# Japanese_spaniel (0.06)
# nipple (0.04)
# Image 495:
# Windsor_tie (0.17)
# pick (0.06)
# plane (0.04)
# Image 496:
# Egyptian_cat (0.49)
# tabby (0.18)
# tiger_cat (0.09)
# Image 497:
# whiskey_jug (0.62)
# nipple (0.04)
# jersey (0.01)
# Image 498:
# kit_fox (0.40)
# grey_fox (0.16)
# coyote (0.13)
# Image 499:
# Siamese_cat (0.25)
# guenon (0.11)
# langur (0.07)
# Image 500:
# timber_wolf (0.21)
# coyote (0.12)
# triceratops (0.06)
# Image 501:
# nipple (0.40)
# Persian_cat (0.05)
# balance_beam (0.03)
# Image 502:
# affenpinscher (0.27)
# Kerry_blue_terrier (0.07)
# curly-coated_retriever (0.06)
# Image 503:
# Persian_cat (0.99)
# Japanese_spaniel (0.00)
# Brabancon_griffon (0.00)
# Image 504:
# fox_squirrel (0.27)
# Madagascar_cat (0.07)
# langur (0.07)
# Image 505:
# lesser_panda (0.41)
# conch (0.05)
# Persian_cat (0.04)
# Image 506:
# Sussex_spaniel (0.69)
# chocolate_sauce (0.03)
# English_foxhound (0.02)
# Image 507:
# table_lamp (0.18)
# cleaver (0.12)
# lampshade (0.06)
# Image 508:
# lynx (0.22)
# tiger_cat (0.15)
# Egyptian_cat (0.13)
# Image 509:
# fox_squirrel (0.16)
# grey_fox (0.12)
# Cardigan (0.06)
# Image 510:
# plane (0.52)
# mousetrap (0.09)
# can_opener (0.05)
# Image 511:
# Dandie_Dinmont (0.12)
# Sussex_spaniel (0.11)
# Norwich_terrier (0.10)
# Image 512:
# redbone (0.35)
# sorrel (0.07)
# rotisserie (0.07)
# Image 513:
# plane (0.58)
# thresher (0.06)
# moving_van (0.03)
# Image 514:
# leopard (0.15)
# whiskey_jug (0.13)
# tiger (0.10)
# Image 515:
# Egyptian_cat (0.50)
# tabby (0.33)
# tiger_cat (0.13)
# Image 516:
# bulletproof_vest (0.12)
# triceratops (0.12)
# Windsor_tie (0.10)
# Image 517:
# lynx (0.45)
# Egyptian_cat (0.06)
# Persian_cat (0.05)
# Image 518:
# Persian_cat (0.99)
# Siamese_cat (0.00)
# kit_fox (0.00)
# Image 519:
# toy_terrier (0.17)
# Egyptian_cat (0.08)
# Boston_bull (0.04)
# Image 520:
# otter (0.13)
# Irish_water_spaniel (0.13)
# fox_squirrel (0.05)
# Image 521:
# toy_terrier (0.46)
# basenji (0.16)
# Egyptian_cat (0.08)
# Image 522:
# nipple (0.12)
# golden_retriever (0.04)
# Windsor_tie (0.04)
# Image 523:
# tabby (0.51)
# tiger_cat (0.19)
# Egyptian_cat (0.11)
# Image 524:
# Persian_cat (0.22)
# tabby (0.15)
# tiger_cat (0.05)
# Image 525:
# meerkat (0.20)
# patas (0.14)
# squirrel_monkey (0.09)
# Image 526:
# milk_can (0.23)
# Crock_Pot (0.10)
# lotion (0.05)
# Image 527:
# Dandie_Dinmont (0.14)
# kit_fox (0.12)
# Persian_cat (0.06)
# Image 528:
# tabby (0.41)
# tiger_cat (0.15)
# Egyptian_cat (0.05)
# Image 529:
# Persian_cat (0.95)
# Japanese_spaniel (0.00)
# dishwasher (0.00)
# Image 530:
# fox_squirrel (0.14)
# Brabancon_griffon (0.07)
# Persian_cat (0.05)
# Image 531:
# hourglass (0.92)
# pedestal (0.02)
# plate_rack (0.00)
# Image 532:
# hourglass (0.93)
# milk_can (0.02)
# Japanese_spaniel (0.01)
# Image 533:
# tiger_cat (0.27)
# tiger (0.25)
# tabby (0.07)
# Image 534:
# fox_squirrel (0.39)
# lion (0.11)
# Egyptian_cat (0.05)
# Image 535:
# tiger_cat (0.09)
# isopod (0.08)
# screen (0.07)
# Image 536:
# Madagascar_cat (0.23)
# fox_squirrel (0.13)
# timber_wolf (0.10)
# Image 537:
# tabby (0.24)
# tiger_cat (0.07)
# Madagascar_cat (0.06)
# Image 538:
# Persian_cat (0.09)
# groenendael (0.07)
# Afghan_hound (0.06)
# Image 539:
# Kerry_blue_terrier (0.12)
# wire-haired_fox_terrier (0.07)
# Japanese_spaniel (0.07)
# Image 540:
# tabby (0.49)
# Egyptian_cat (0.10)
# tiger_cat (0.08)
# Image 541:
# kit_fox (0.19)
# groenendael (0.08)
# kelpie (0.06)
# Image 542:
# Sealyham_terrier (0.19)
# can_opener (0.09)
# Japanese_spaniel (0.07)
# Image 543:
# langur (0.49)
# patas (0.08)
# indri (0.07)
# Image 544:
# chiffonier (0.10)
# Brabancon_griffon (0.10)
# thresher (0.06)
# Image 545:
# moving_van (0.04)
# Walker_hound (0.03)
# revolver (0.03)
# Image 546:
# marmoset (0.31)
# fox_squirrel (0.10)
# tabby (0.07)
# Image 547:
# Japanese_spaniel (0.09)
# wire-haired_fox_terrier (0.08)
# Shetland_sheepdog (0.08)
# Image 548:
# bobsled (0.13)
# waffle_iron (0.10)
# dishwasher (0.07)
# Image 549:
# Japanese_spaniel (0.81)
# toy_terrier (0.02)
# papillon (0.01)
# Image 550:
# carton (0.15)
# toy_terrier (0.11)
# wire-haired_fox_terrier (0.05)
# Image 551:
# Japanese_spaniel (0.17)
# Madagascar_cat (0.11)
# colobus (0.10)
# Image 552:
# fox_squirrel (0.66)
# marmoset (0.05)
# barn_spider (0.04)
# Image 553:
# Bedlington_terrier (0.35)
# polecat (0.13)
# platypus (0.07)
# Image 554:
# English_foxhound (0.12)
# Walker_hound (0.11)
# Japanese_spaniel (0.05)
# Image 555:
# lighter (0.06)
# eggnog (0.04)
# punching_bag (0.04)
# Image 556:
# lesser_panda (0.41)
# polecat (0.19)
# tiger (0.08)
# Image 557:
# marmoset (0.95)
# patas (0.02)
# langur (0.01)
# Image 558:
# magnetic_compass (0.15)
# ping-pong_ball (0.12)
# bearskin (0.07)
# Image 559:
# Persian_cat (0.25)
# Pomeranian (0.15)
# kit_fox (0.05)
# Image 560:
# fox_squirrel (0.32)
# macaque (0.06)
# marmoset (0.04)
# Image 561:
# Great_Dane (0.40)
# dingo (0.10)
# English_foxhound (0.08)
# Image 562:
# rotisserie (0.23)
# triceratops (0.08)
# muzzle (0.04)
# Image 563:
# triceratops (0.37)
# red_wolf (0.08)
# African_hunting_dog (0.07)
# Image 564:
# patas (0.30)
# fox_squirrel (0.28)
# toy_terrier (0.10)
# Image 565:
# EntleBucher (0.47)
# rock_beauty (0.12)
# goldfish (0.04)
# Image 566:
# Australian_terrier (0.15)
# fox_squirrel (0.04)
# Norwich_terrier (0.04)
# Image 567:
# triceratops (0.19)
# rock_beauty (0.16)
# fox_squirrel (0.03)
# Image 568:
# theater_curtain (0.34)
# Irish_water_spaniel (0.08)
# moving_van (0.03)
# Image 569:
# Egyptian_cat (0.14)
# tiger_cat (0.14)
# tabby (0.10)
# Image 570:
# wire-haired_fox_terrier (0.42)
# Walker_hound (0.09)
# English_foxhound (0.08)
# Image 571:
# polecat (0.78)
# black-footed_ferret (0.11)
# lesser_panda (0.03)
# Image 572:
# screen (0.57)
# tiger_cat (0.14)
# television (0.04)
# Image 573:
# kit_fox (0.44)
# red_fox (0.09)
# grey_fox (0.08)
# Image 574:
# sorrel (0.30)
# English_foxhound (0.08)
# bearskin (0.04)
# Image 575:
# Sussex_spaniel (0.23)
# chain_saw (0.14)
# golden_retriever (0.06)
# Image 576:
# packet (0.10)
# book_jacket (0.09)
# polecat (0.08)
# Image 577:
# schipperke (0.16)
# Norwegian_elkhound (0.06)
# Persian_cat (0.04)
# Image 578:
# tiger (0.11)
# lynx (0.08)
# tiger_cat (0.08)
# Image 579:
# Persian_cat (0.74)
# Egyptian_cat (0.08)
# Siamese_cat (0.03)
# Image 580:
# redbone (0.23)
# English_foxhound (0.06)
# toy_terrier (0.04)
# Image 581:
# indri (0.80)
# Japanese_spaniel (0.04)
# Madagascar_cat (0.04)
# Image 582:
# moving_van (0.41)
# marmoset (0.10)
# thresher (0.03)
# Image 583:
# iron (0.16)
# toy_terrier (0.08)
# EntleBucher (0.05)
# Image 584:
# tabby (0.10)
# can_opener (0.08)
# Persian_cat (0.07)
# Image 585:
# milk_can (0.09)
# whiskey_jug (0.04)
# punching_bag (0.03)
# Image 586:
# milk_can (0.19)
# dishwasher (0.13)
# spatula (0.09)
# Image 587:
# fox_squirrel (0.49)
# marmoset (0.03)
# Windsor_tie (0.02)
# Image 588:
# tiger_cat (0.32)
# tabby (0.30)
# tiger (0.06)
# Image 589:
# lesser_panda (0.39)
# marmoset (0.08)
# polecat (0.05)
# Image 590:
# tiger_cat (0.47)
# Egyptian_cat (0.29)
# tabby (0.14)
# Image 591:
# Japanese_spaniel (0.73)
# papillon (0.01)
# marmoset (0.01)
# Image 592:
# clumber (0.43)
# nipple (0.10)
# Sealyham_terrier (0.05)
# Image 593:
# fox_squirrel (0.28)
# Mexican_hairless (0.06)
# coyote (0.06)
# Image 594:
# indri (0.73)
# Madagascar_cat (0.05)
# oystercatcher (0.00)
# Image 595:
# Eskimo_dog (0.13)
# Persian_cat (0.12)
# Siamese_cat (0.07)
# Image 596:
# chiton (0.03)
# fox_squirrel (0.03)
# marmoset (0.02)
# Image 597:
# Walker_hound (0.63)
# English_foxhound (0.28)
# toy_terrier (0.01)
# Image 598:
# Persian_cat (0.18)
# tabby (0.11)
# tiger_cat (0.06)
# Image 599:
# tabby (0.28)
# Egyptian_cat (0.11)
# Persian_cat (0.09)
# Image 600:
# polecat (0.18)
# weasel (0.18)
# mongoose (0.10)
# Image 601:
# tiger_cat (0.19)
# Egyptian_cat (0.15)
# marmoset (0.05)
# Image 602:
# triceratops (0.06)
# chain_saw (0.05)
# maraca (0.05)
# Image 603:
# fox_squirrel (0.23)
# rock_beauty (0.16)
# dhole (0.06)
# Image 604:
# Japanese_spaniel (0.26)
# wire-haired_fox_terrier (0.13)
# papillon (0.05)
# Image 605:
# nipple (0.67)
# safety_pin (0.03)
# hourglass (0.01)
# Image 606:
# tabby (0.12)
# fox_squirrel (0.10)
# EntleBucher (0.07)
# Image 607:
# Windsor_tie (0.32)
# bulletproof_vest (0.10)
# colobus (0.04)
# Image 608:
# Egyptian_cat (0.39)
# indri (0.07)
# fox_squirrel (0.03)
# Image 609:
# tobacco_shop (0.11)
# milk_can (0.07)
# pot (0.06)
# Image 610:
# Walker_hound (0.12)
# overskirt (0.10)
# English_foxhound (0.09)
# Image 611:
# tiger_cat (0.08)
# panpipe (0.04)
# leopard (0.03)
# Image 612:
# chambered_nautilus (0.75)
# bighorn (0.19)
# sidewinder (0.01)
# Image 613:
# lion (0.10)
# hartebeest (0.09)
# hyena (0.07)
# Image 614:
# milk_can (0.17)
# American_lobster (0.15)
# fox_squirrel (0.05)
# Image 615:
# Egyptian_cat (0.07)
# muzzle (0.03)
# shoji (0.03)
# Image 616:
# Persian_cat (0.42)
# tiger_cat (0.08)
# tabby (0.05)
# Image 617:
# polecat (0.11)
# platypus (0.05)
# abaya (0.05)
# Image 618:
# milk_can (0.10)
# tabby (0.08)
# fox_squirrel (0.05)
# Image 619:
# Persian_cat (0.12)
# squirrel_monkey (0.08)
# fox_squirrel (0.07)
# Image 620:
# tabby (0.31)
# Egyptian_cat (0.07)
# fox_squirrel (0.06)
# Image 621:
# rotisserie (0.11)
# Brabancon_griffon (0.09)
# otterhound (0.04)
# Image 622:
# indri (0.25)
# Madagascar_cat (0.08)
# EntleBucher (0.05)
# Image 623:
# Egyptian_cat (0.25)
# tabby (0.10)
# kit_fox (0.05)
# Image 624:
# wire-haired_fox_terrier (0.72)
# Kerry_blue_terrier (0.03)
# English_foxhound (0.03)
# Image 625:
# bearskin (0.46)
# moving_van (0.04)
# bobsled (0.03)
# Image 626:
# Persian_cat (0.27)
# tabby (0.11)
# tiger_cat (0.08)
# Image 627:
# hatchet (0.11)
# barn_spider (0.08)
# iron (0.04)
# Image 628:
# fox_squirrel (0.32)
# coyote (0.10)
# Madagascar_cat (0.07)
# Image 629:
# revolver (0.28)
# ant (0.07)
# bluetick (0.06)
# Image 630:
# EntleBucher (0.33)
# Japanese_spaniel (0.07)
# Madagascar_cat (0.06)
# Image 631:
# Egyptian_cat (0.54)
# Siamese_cat (0.07)
# lynx (0.06)
# Image 632:
# Japanese_spaniel (0.32)
# toy_terrier (0.10)
# EntleBucher (0.06)
# Image 633:
# theater_curtain (0.16)
# Persian_cat (0.05)
# velvet (0.04)
# Image 634:
# toilet_seat (0.40)
# consomme (0.09)
# pick (0.08)
# Image 635:
# frilled_lizard (0.12)
# tiger (0.08)
# tabby (0.05)
# Image 636:
# lynx (0.41)
# tiger (0.11)
# tiger_cat (0.11)
# Image 637:
# triceratops (0.20)
# Indian_elephant (0.07)
# tusker (0.04)
# Image 638:
# custard_apple (0.50)
# weasel (0.06)
# bell_pepper (0.04)
# Image 639:
# Japanese_spaniel (0.27)
# Persian_cat (0.15)
# Pekinese (0.12)
# Image 640:
# muzzle (0.10)
# toy_terrier (0.08)
# bobsled (0.07)
# Image 641:
# Persian_cat (0.49)
# hamster (0.08)
# nipple (0.04)
# Image 642:
# nipple (0.25)
# lotion (0.15)
# oil_filter (0.06)
# Image 643:
# eggnog (0.49)
# lotion (0.13)
# whiskey_jug (0.12)
# Image 644:
# Irish_water_spaniel (0.10)
# bearskin (0.05)
# affenpinscher (0.03)
# Image 645:
# English_foxhound (0.07)
# bearskin (0.05)
# overskirt (0.05)
# Image 646:
# Eskimo_dog (0.08)
# Siamese_cat (0.04)
# Walker_hound (0.04)
# Image 647:
# goldfish (0.15)
# chain_saw (0.14)
# rock_beauty (0.08)
# Image 648:
# shoji (0.20)
# fire_screen (0.09)
# Windsor_tie (0.04)
# Image 649:
# chiffonier (0.45)
# chain_saw (0.08)
# entertainment_center (0.03)
# Image 650:
# tabby (0.34)
# milk_can (0.13)
# Egyptian_cat (0.07)
# Image 651:
# Japanese_spaniel (0.86)
# Walker_hound (0.03)
# English_foxhound (0.01)
# Image 652:
# Walker_hound (0.30)
# Saint_Bernard (0.06)
# English_foxhound (0.05)
# Image 653:
# Persian_cat (0.84)
# Arctic_fox (0.01)
# marmoset (0.01)
# Image 654:
# black-and-tan_coonhound (0.13)
# Walker_hound (0.11)
# bluetick (0.07)
# Image 655:
# dingo (0.28)
# red_wolf (0.17)
# kit_fox (0.08)
# Image 656:
# toy_terrier (0.32)
# Mexican_hairless (0.29)
# triceratops (0.17)
# Image 657:
# Egyptian_cat (0.14)
# tabby (0.10)
# tiger_cat (0.07)
# Image 658:
# isopod (0.06)
# spider_monkey (0.06)
# tiger_beetle (0.04)
# Image 659:
# kit_fox (0.59)
# red_fox (0.06)
# fox_squirrel (0.04)
# Image 660:
# German_short-haired_pointer (0.58)
# Walker_hound (0.08)
# bluetick (0.08)
# Image 661:
# fox_squirrel (0.15)
# marmoset (0.14)
# milk_can (0.07)
# Image 662:
# neck_brace (0.17)
# milk_can (0.03)
# pedestal (0.02)
# Image 663:
# milk_can (0.36)
# espresso_maker (0.08)
# whiskey_jug (0.07)
# Image 664:
# waffle_iron (0.11)
# lotion (0.05)
# muzzle (0.04)
# Image 665:
# lesser_panda (0.48)
# red_fox (0.15)
# basenji (0.06)
# Image 666:
# gibbon (0.35)
# langur (0.26)
# colobus (0.05)
# Image 667:
# abaya (0.18)
# bulletproof_vest (0.05)
# black-and-tan_coonhound (0.03)
# Image 668:
# whiskey_jug (0.49)
# book_jacket (0.03)
# pedestal (0.02)
# Image 669:
# Windsor_tie (0.17)
# English_foxhound (0.05)
# wire-haired_fox_terrier (0.04)
# Image 670:
# lion (0.15)
# cougar (0.14)
# Persian_cat (0.11)
# Image 671:
# Egyptian_cat (0.21)
# polecat (0.06)
# tabby (0.03)
# Image 672:
# fox_squirrel (0.57)
# macaque (0.03)
# lion (0.03)
# Image 673:
# tabby (0.11)
# coyote (0.10)
# dhole (0.08)
# Image 674:
# eggnog (0.18)
# tabby (0.17)
# Egyptian_cat (0.12)
# Image 675:
# German_short-haired_pointer (0.24)
# redbone (0.13)
# Sussex_spaniel (0.06)
# Image 676:
# Japanese_spaniel (0.14)
# overskirt (0.05)
# safety_pin (0.04)
# Image 677:
# tabby (0.52)
# Persian_cat (0.14)
# tiger_cat (0.10)
# Image 678:
# bulletproof_vest (0.16)
# espresso_maker (0.11)
# waffle_iron (0.05)
# Image 679:
# Persian_cat (0.97)
# pirate (0.00)
# Japanese_spaniel (0.00)
# Image 680:
# killer_whale (0.10)
# pinwheel (0.07)
# otter (0.04)
# Image 681:
# Japanese_spaniel (0.09)
# Windsor_tie (0.08)
# Dandie_Dinmont (0.05)
# Image 682:
# magnetic_compass (0.69)
# tick (0.05)
# barn_spider (0.02)
# Image 683:
# dishwasher (0.33)
# space_bar (0.04)
# muzzle (0.03)
# Image 684:
# Persian_cat (0.67)
# Siamese_cat (0.02)
# fox_squirrel (0.01)
# Image 685:
# indri (0.61)
# Madagascar_cat (0.15)
# EntleBucher (0.09)
# Image 686:
# triceratops (0.10)
# rock_beauty (0.08)
# chain_saw (0.05)
# Image 687:
# Pomeranian (0.37)
# Persian_cat (0.18)
# kit_fox (0.10)
# Image 688:
# EntleBucher (0.16)
# black-and-tan_coonhound (0.07)
# polecat (0.05)
# Image 689:
# lion (0.15)
# Persian_cat (0.09)
# dhole (0.07)
# Image 690:
# lesser_panda (0.31)
# polecat (0.25)
# black-footed_ferret (0.06)
# Image 691:
# eggnog (0.05)
# Japanese_spaniel (0.03)
# marmoset (0.03)
# Image 692:
# tiger (0.20)
# magnetic_compass (0.09)
# leopard (0.06)
# Image 693:
# plane (0.04)
# Walker_hound (0.03)
# African_hunting_dog (0.03)
# Image 694:
# nipple (0.08)
# Windsor_tie (0.06)
# Dandie_Dinmont (0.05)
# Image 695:
# capuchin (0.40)
# marmoset (0.18)
# langur (0.10)
# Image 696:
# Persian_cat (0.37)
# lynx (0.10)
# tiger_cat (0.09)
# Image 697:
# Japanese_spaniel (0.13)
# Persian_cat (0.09)
# affenpinscher (0.05)
# Image 698:
# Pomeranian (0.14)
# Persian_cat (0.08)
# hamster (0.05)
# Image 699:
# Egyptian_cat (0.11)
# Norwich_terrier (0.08)
# tiger_cat (0.08)
# Image 700:
# Madagascar_cat (0.18)
# spotlight (0.06)
# loupe (0.05)
# Image 701:
# Sussex_spaniel (0.33)
# golden_retriever (0.08)
# platypus (0.07)
# Image 702:
# Cardigan (0.06)
# kit_fox (0.05)
# dingo (0.04)
# Image 703:
# triceratops (0.09)
# Dandie_Dinmont (0.05)
# langur (0.04)
# Image 704:
# lynx (0.12)
# coyote (0.05)
# kit_fox (0.04)
# Image 705:
# EntleBucher (0.22)
# grey_fox (0.08)
# Walker_hound (0.07)
# Image 706:
# Japanese_spaniel (0.47)
# Blenheim_spaniel (0.10)
# papillon (0.05)
# Image 707:
# Persian_cat (0.90)
# marmoset (0.05)
# Japanese_spaniel (0.04)
# Image 708:
# tabby (0.65)
# Egyptian_cat (0.18)
# tiger_cat (0.09)
# Image 709:
# tiger (0.88)
# tiger_cat (0.07)
# leopard (0.01)
# Image 710:
# leopard (0.68)
# tiger (0.11)
# jaguar (0.06)
# Image 711:
# banded_gecko (0.20)
# Walker_hound (0.11)
# English_foxhound (0.08)
# Image 712:
# espresso_maker (0.85)
# cocktail_shaker (0.03)
# can_opener (0.02)
# Image 713:
# tiger (0.51)
# tiger_cat (0.17)
# Persian_cat (0.07)
# Image 714:
# Blenheim_spaniel (0.14)
# langur (0.11)
# Japanese_spaniel (0.05)
# Image 715:
# punching_bag (0.22)
# hair_spray (0.05)
# screen (0.05)
# Image 716:
# Sussex_spaniel (0.14)
# Norwich_terrier (0.05)
# fox_squirrel (0.05)
# Image 717:
# Siamese_cat (0.42)
# Brabancon_griffon (0.06)
# lesser_panda (0.03)
# Image 718:
# triceratops (0.17)
# custard_apple (0.06)
# fox_squirrel (0.04)
# Image 719:
# Japanese_spaniel (0.25)
# skunk (0.09)
# clog (0.06)
# Image 720:
# Egyptian_cat (0.36)
# tiger_cat (0.20)
# Persian_cat (0.04)
# Image 721:
# Persian_cat (0.10)
# EntleBucher (0.09)
# patas (0.05)
# Image 722:
# Persian_cat (0.10)
# dishwasher (0.05)
# black_grouse (0.04)
# Image 723:
# EntleBucher (0.19)
# Walker_hound (0.07)
# toy_terrier (0.06)
# Image 724:
# German_shepherd (0.15)
# EntleBucher (0.09)
# Australian_terrier (0.06)
# Image 725:
# black_stork (0.13)
# isopod (0.09)
# black_grouse (0.06)
# Image 726:
# Egyptian_cat (0.15)
# tabby (0.12)
# fox_squirrel (0.12)
# Image 727:
# Egyptian_cat (0.48)
# tabby (0.26)
# tiger_cat (0.21)
# Image 728:
# dhole (0.10)
# lion (0.08)
# EntleBucher (0.08)
# Image 729:
# bearskin (0.23)
# chain_saw (0.06)
# milk_can (0.05)
# Image 730:
# nipple (0.26)
# sunscreen (0.13)
# Band_Aid (0.06)
# Image 731:
# espresso_maker (0.15)
# toy_terrier (0.07)
# plane (0.07)
# Image 732:
# langur (0.15)
# marmoset (0.10)
# cassette_player (0.06)
# Image 733:
# cocktail_shaker (0.39)
# whiskey_jug (0.08)
# lotion (0.05)
# ...
# EntleBucher (0.06)
# Image 4759:
# maraca (0.05)
# cocktail_shaker (0.03)
# magnetic_compass (0.02)
# Image 4760:
# punching_bag (0.12)
# bearskin (0.10)
# milk_can (0.10)
# Image 4761:
# plane (0.28)
# revolver (0.09)
# can_opener (0.04)
# Image 4762:
# whiskey_jug (0.21)
# nipple (0.07)
# espresso_maker (0.05)
# Image 4763:
# lotion (0.20)
# eggnog (0.09)
# carton (0.06)
# Image 4764:
# Egyptian_cat (0.63)
# tabby (0.24)
# tiger_cat (0.03)
# Image 4765:
# plane (0.97)
# can_opener (0.00)
# eggnog (0.00)
# Image 4766:
# fox_squirrel (0.15)
# red_wolf (0.13)
# grey_fox (0.07)
# Image 4767:
# chain_saw (0.43)
# waffle_iron (0.03)
# milk_can (0.03)
# Image 4768:
# Walker_hound (0.43)
# English_foxhound (0.39)
# basenji (0.03)
# Image 4769:
# Japanese_spaniel (0.36)
# Madagascar_cat (0.14)
# indri (0.08)
# Image 4770:
# Japanese_spaniel (0.08)
# German_short-haired_pointer (0.04)
# platypus (0.04)
# Image 4771:
# eggnog (0.24)
# punching_bag (0.13)
# plunger (0.12)
# Image 4772:
# lesser_panda (0.36)
# English_foxhound (0.05)
# Walker_hound (0.05)
# Image 4773:
# Cardigan (0.20)
# Border_collie (0.14)
# EntleBucher (0.10)
# Image 4774:
# giant_panda (0.17)
# Japanese_spaniel (0.17)
# Sealyham_terrier (0.12)
# Image 4775:
# bearskin (0.07)
# mitten (0.07)
# Christmas_stocking (0.06)
# Image 4776:
# panpipe (0.07)
# lesser_panda (0.05)
# marmoset (0.03)
# Image 4777:
# hourglass (0.21)
# marmoset (0.11)
# guillotine (0.07)
# Image 4778:
# Japanese_spaniel (0.28)
# guinea_pig (0.04)
# Angora (0.04)
# Image 4779:
# tabby (0.32)
# Egyptian_cat (0.07)
# lynx (0.07)
# Image 4780:
# American_black_bear (0.45)
# brown_bear (0.13)
# schipperke (0.07)
# Image 4781:
# bobsled (0.49)
# black_grouse (0.10)
# bulbul (0.04)
# Image 4782:
# Japanese_spaniel (0.35)
# wire-haired_fox_terrier (0.35)
# Sussex_spaniel (0.02)
# Image 4783:
# Japanese_spaniel (0.17)
# Eskimo_dog (0.15)
# malamute (0.05)
# Image 4784:
# Doberman (0.13)
# rock_beauty (0.11)
# kelpie (0.09)
# Image 4785:
# polecat (0.07)
# capuchin (0.07)
# otterhound (0.06)
# Image 4786:
# milk_can (0.62)
# lotion (0.05)
# can_opener (0.04)
# Image 4787:
# packet (0.18)
# panpipe (0.10)
# head_cabbage (0.05)
# Image 4788:
# toy_terrier (0.03)
# bulletproof_vest (0.03)
# rock_beauty (0.03)
# Image 4789:
# marmoset (0.09)
# Sussex_spaniel (0.07)
# thresher (0.06)
# Image 4790:
# tabby (0.69)
# Egyptian_cat (0.19)
# tiger_cat (0.06)
# Image 4791:
# EntleBucher (0.47)
# Bernese_mountain_dog (0.16)
# Greater_Swiss_Mountain_dog (0.06)
# Image 4792:
# Shetland_sheepdog (0.42)
# keeshond (0.08)
# collie (0.07)
# Image 4793:
# pedestal (0.48)
# chiffonier (0.05)
# eggnog (0.04)
# Image 4794:
# plate_rack (0.66)
# nipple (0.12)
# clog (0.05)
# Image 4795:
# triceratops (0.11)
# Mexican_hairless (0.09)
# German_short-haired_pointer (0.06)
# Image 4796:
# Persian_cat (0.21)
# tabby (0.06)
# Madagascar_cat (0.06)
# Image 4797:
# affenpinscher (0.11)
# Irish_water_spaniel (0.06)
# amphibian (0.04)
# Image 4798:
# chain_saw (0.17)
# whistle (0.07)
# muzzle (0.03)
# Image 4799:
# fox_squirrel (0.08)
# milk_can (0.06)
# Madagascar_cat (0.04)
# Image 4800:
# tabby (0.21)
# Persian_cat (0.10)
# screen (0.04)
# Image 4801:
# whiskey_jug (0.13)
# langur (0.06)
# milk_can (0.06)
# Image 4802:
# Egyptian_cat (0.31)
# tiger_cat (0.06)
# grey_fox (0.04)
# Image 4803:
# magnetic_compass (0.09)
# pot (0.08)
# milk_can (0.05)
# Image 4804:
# Persian_cat (0.19)
# Japanese_spaniel (0.07)
# tabby (0.03)
# Image 4805:
# polecat (0.07)
# fox_squirrel (0.04)
# Great_Dane (0.04)
# Image 4806:
# clog (0.18)
# guillotine (0.13)
# thresher (0.09)
# Image 4807:
# German_shepherd (0.45)
# toy_terrier (0.03)
# muzzle (0.03)
# Image 4808:
# plate_rack (0.19)
# cradle (0.06)
# bolo_tie (0.04)
# Image 4809:
# Persian_cat (0.23)
# Japanese_spaniel (0.04)
# Siamese_cat (0.03)
# Image 4810:
# cocktail_shaker (0.37)
# nipple (0.09)
# hourglass (0.09)
# Image 4811:
# bulletproof_vest (0.13)
# breastplate (0.04)
# cuirass (0.03)
# Image 4812:
# Siamese_cat (0.20)
# Persian_cat (0.14)
# Egyptian_cat (0.03)
# Image 4813:
# Mexican_hairless (0.17)
# fox_squirrel (0.09)
# langur (0.09)
# Image 4814:
# patas (0.30)
# Madagascar_cat (0.14)
# indri (0.06)
# Image 4815:
# jersey (0.06)
# book_jacket (0.04)
# Windsor_tie (0.04)
# Image 4816:
# black-and-tan_coonhound (0.47)
# EntleBucher (0.12)
# abaya (0.05)
# Image 4817:
# Walker_hound (0.58)
# English_foxhound (0.29)
# EntleBucher (0.05)
# Image 4818:
# Walker_hound (0.35)
# English_foxhound (0.14)
# EntleBucher (0.07)
# Image 4819:
# EntleBucher (0.16)
# Windsor_tie (0.16)
# Greater_Swiss_Mountain_dog (0.03)
# Image 4820:
# affenpinscher (0.08)
# Japanese_spaniel (0.07)
# colobus (0.06)
# Image 4821:
# gong (0.12)
# tabby (0.08)
# Persian_cat (0.08)
# Image 4822:
# basenji (0.11)
# tiger_cat (0.08)
# banded_gecko (0.07)
# Image 4823:
# triceratops (0.42)
# maraca (0.12)
# banded_gecko (0.03)
# Image 4824:
# punching_bag (0.99)
# Windsor_tie (0.01)
# milk_can (0.00)
# Image 4825:
# space_shuttle (0.19)
# dishwasher (0.08)
# lotion (0.05)
# Image 4826:
# bolo_tie (0.23)
# letter_opener (0.06)
# can_opener (0.04)
# Image 4827:
# Windsor_tie (0.24)
# abaya (0.23)
# bulletproof_vest (0.07)
# Image 4828:
# platypus (0.15)
# axolotl (0.11)
# goldfish (0.05)
# Image 4829:
# Japanese_spaniel (0.62)
# Persian_cat (0.03)
# wire-haired_fox_terrier (0.02)
# Image 4830:
# fox_squirrel (0.53)
# wood_rabbit (0.08)
# marmoset (0.05)
# Image 4831:
# German_shepherd (0.25)
# toy_terrier (0.17)
# Brabancon_griffon (0.15)
# Image 4832:
# lynx (0.26)
# Egyptian_cat (0.25)
# tabby (0.11)
# Image 4833:
# yawl (0.24)
# moving_van (0.23)
# lotion (0.03)
# Image 4834:
# rock_beauty (0.41)
# red_fox (0.04)
# goldfish (0.04)
# Image 4835:
# plastic_bag (0.09)
# pedestal (0.09)
# milk_can (0.04)
# Image 4836:
# English_foxhound (0.22)
# Walker_hound (0.09)
# Japanese_spaniel (0.04)
# Image 4837:
# fox_squirrel (0.33)
# lion (0.10)
# redbone (0.09)
# Image 4838:
# tiger_cat (0.28)
# lynx (0.22)
# tabby (0.14)
# Image 4839:
# lynx (0.65)
# tabby (0.05)
# Egyptian_cat (0.04)
# Image 4840:
# toy_terrier (0.09)
# Siamese_cat (0.05)
# plane (0.03)
# Image 4841:
# Blenheim_spaniel (0.18)
# English_foxhound (0.16)
# lesser_panda (0.06)
# Image 4842:
# fox_squirrel (0.92)
# Madagascar_cat (0.01)
# kit_fox (0.01)
# Image 4843:
# Egyptian_cat (0.06)
# toy_terrier (0.04)
# basenji (0.04)
# Image 4844:
# sorrel (0.30)
# strawberry (0.04)
# langur (0.04)
# Image 4845:
# tabby (0.50)
# tiger_cat (0.09)
# lynx (0.07)
# Image 4846:
# patas (0.29)
# chimpanzee (0.14)
# orangutan (0.13)
# Image 4847:
# Windsor_tie (0.27)
# Japanese_spaniel (0.21)
# colobus (0.03)
# Image 4848:
# Siamese_cat (0.88)
# can_opener (0.00)
# Egyptian_cat (0.00)
# Image 4849:
# tabby (0.78)
# tiger_cat (0.09)
# Egyptian_cat (0.05)
# Image 4850:
# milk_can (0.16)
# patas (0.13)
# tiger (0.03)
# Image 4851:
# chain_saw (0.07)
# revolver (0.06)
# crane (0.05)
# Image 4852:
# tabby (0.37)
# tiger_cat (0.16)
# Egyptian_cat (0.14)
# Image 4853:
# triceratops (0.55)
# Sussex_spaniel (0.24)
# Irish_water_spaniel (0.02)
# Image 4854:
# lynx (0.22)
# lion (0.10)
# fox_squirrel (0.08)
# Image 4855:
# tabby (0.44)
# Egyptian_cat (0.16)
# tiger_cat (0.07)
# Image 4856:
# Japanese_spaniel (0.41)
# bluetick (0.18)
# German_short-haired_pointer (0.06)
# Image 4857:
# tabby (0.09)
# Persian_cat (0.09)
# tiger_cat (0.08)
# Image 4858:
# tabby (0.34)
# Egyptian_cat (0.15)
# meerkat (0.10)
# Image 4859:
# waffle_iron (0.33)
# milk_can (0.05)
# mousetrap (0.02)
# Image 4860:
# pedestal (0.32)
# throne (0.10)
# moving_van (0.08)
# Image 4861:
# patas (0.49)
# marmoset (0.21)
# langur (0.13)
# Image 4862:
# toy_terrier (0.28)
# papillon (0.24)
# Japanese_spaniel (0.09)
# Image 4863:
# grey_fox (0.19)
# fox_squirrel (0.14)
# kit_fox (0.12)
# Image 4864:
# kit_fox (0.42)
# red_fox (0.27)
# grey_fox (0.04)
# Image 4865:
# lion (0.11)
# tiger (0.07)
# book_jacket (0.06)
# Image 4866:
# Norwich_terrier (0.52)
# Australian_terrier (0.08)
# Brabancon_griffon (0.04)
# Image 4867:
# schipperke (0.29)
# kelpie (0.12)
# dingo (0.04)
# Image 4868:
# tiger_cat (0.56)
# Egyptian_cat (0.16)
# tabby (0.14)
# Image 4869:
# toy_terrier (0.42)
# Siamese_cat (0.22)
# wire-haired_fox_terrier (0.09)
# Image 4870:
# plate_rack (0.34)
# espresso_maker (0.14)
# eggnog (0.09)
# Image 4871:
# Egyptian_cat (0.14)
# tabby (0.12)
# fox_squirrel (0.09)
# Image 4872:
# basenji (0.12)
# Egyptian_cat (0.12)
# Chihuahua (0.11)
# Image 4873:
# milk_can (0.91)
# whiskey_jug (0.02)
# book_jacket (0.01)
# Image 4874:
# Japanese_spaniel (0.35)
# Blenheim_spaniel (0.18)
# milk_can (0.02)
# Image 4875:
# bluetick (0.29)
# tabby (0.05)
# Walker_hound (0.05)
# Image 4876:
# moving_van (0.33)
# screen (0.06)
# guillotine (0.05)
# Image 4877:
# Madagascar_cat (0.60)
# English_foxhound (0.06)
# EntleBucher (0.05)
# Image 4878:
# marmoset (0.40)
# fox_squirrel (0.13)
# mink (0.02)
# Image 4879:
# Walker_hound (0.68)
# Japanese_spaniel (0.05)
# EntleBucher (0.04)
# Image 4880:
# bluetick (0.28)
# Japanese_spaniel (0.06)
# German_short-haired_pointer (0.05)
# Image 4881:
# Madagascar_cat (0.43)
# langur (0.09)
# fox_squirrel (0.04)
# Image 4882:
# kelpie (0.14)
# bulletproof_vest (0.09)
# ski_mask (0.07)
# Image 4883:
# tabby (0.51)
# Egyptian_cat (0.23)
# tiger_cat (0.11)
# Image 4884:
# lesser_panda (0.29)
# EntleBucher (0.14)
# Appenzeller (0.03)
# Image 4885:
# wire-haired_fox_terrier (0.09)
# hog (0.06)
# Yorkshire_terrier (0.05)
# Image 4886:
# skunk (0.17)
# bearskin (0.10)
# pick (0.09)
# Image 4887:
# Sussex_spaniel (0.08)
# platypus (0.05)
# Saint_Bernard (0.05)
# Image 4888:
# Egyptian_cat (0.10)
# Walker_hound (0.04)
# tabby (0.03)
# Image 4889:
# Japanese_spaniel (0.07)
# red_wolf (0.04)
# Persian_cat (0.04)
# Image 4890:
# toy_terrier (0.17)
# schipperke (0.11)
# Mexican_hairless (0.05)
# Image 4891:
# Egyptian_cat (0.35)
# Siamese_cat (0.35)
# tabby (0.04)
# Image 4892:
# Japanese_spaniel (0.26)
# EntleBucher (0.23)
# Persian_cat (0.11)
# Image 4893:
# tabby (0.65)
# Persian_cat (0.22)
# tiger_cat (0.06)
# Image 4894:
# dingo (0.18)
# basenji (0.08)
# lion (0.05)
# Image 4895:
# screen (0.25)
# Persian_cat (0.21)
# Japanese_spaniel (0.12)
# Image 4896:
# Persian_cat (0.18)
# fox_squirrel (0.05)
# Egyptian_cat (0.05)
# Image 4897:
# tiger_cat (0.41)
# tabby (0.37)
# tiger (0.17)
# Image 4898:
# marmoset (0.83)
# capuchin (0.06)
# langur (0.03)
# Image 4899:
# Sussex_spaniel (0.55)
# Persian_cat (0.06)
# triceratops (0.03)
# Image 4900:
# dalmatian (0.08)
# pick (0.08)
# muzzle (0.07)
# Image 4901:
# marmoset (0.31)
# Japanese_spaniel (0.08)
# indri (0.04)
# Image 4902:
# Windsor_tie (0.66)
# loupe (0.14)
# revolver (0.03)
# Image 4903:
# fox_squirrel (0.18)
# screen (0.09)
# hourglass (0.04)
# Image 4904:
# milk_can (0.43)
# Walker_hound (0.06)
# English_foxhound (0.05)
# Image 4905:
# tabby (0.43)
# tiger_cat (0.15)
# Egyptian_cat (0.15)
# Image 4906:
# nipple (0.23)
# Walker_hound (0.06)
# redbone (0.05)
# Image 4907:
# muzzle (0.17)
# rock_beauty (0.07)
# Windsor_tie (0.04)
# Image 4908:
# Madagascar_cat (0.30)
# langur (0.10)
# patas (0.10)
# Image 4909:
# papillon (0.38)
# Japanese_spaniel (0.25)
# toy_terrier (0.01)
# Image 4910:
# screen (0.85)
# Persian_cat (0.03)
# carton (0.02)
# Image 4911:
# kit_fox (0.63)
# coyote (0.16)
# grey_fox (0.03)
# Image 4912:
# fox_squirrel (0.41)
# macaque (0.14)
# patas (0.06)
# Image 4913:
# book_jacket (0.11)
# jersey (0.08)
# whiskey_jug (0.07)
# Image 4914:
# nipple (0.86)
# table_lamp (0.01)
# saltshaker (0.01)
# Image 4915:
# bearskin (0.87)
# clog (0.02)
# punching_bag (0.01)
# Image 4916:
# plane (0.18)
# spatula (0.04)
# clog (0.03)
# Image 4917:
# Windsor_tie (0.47)
# yawl (0.03)
# cleaver (0.02)
# Image 4918:
# milk_can (0.51)
# potter's_wheel (0.16)
# eggnog (0.15)
# Image 4919:
# whiskey_jug (0.23)
# nipple (0.03)
# face_powder (0.02)
# Image 4920:
# Japanese_spaniel (0.59)
# Bernese_mountain_dog (0.06)
# Border_collie (0.05)
# Image 4921:
# Egyptian_cat (0.21)
# tiger_cat (0.11)
# lynx (0.09)
# Image 4922:
# Australian_terrier (0.12)
# Yorkshire_terrier (0.04)
# orangutan (0.03)
# Image 4923:
# gazelle (0.15)
# polecat (0.06)
# indri (0.04)
# Image 4924:
# nipple (0.13)
# Petri_dish (0.06)
# brassiere (0.04)
# Image 4925:
# langur (0.55)
# capuchin (0.09)
# patas (0.09)
# Image 4926:
# Walker_hound (0.14)
# colobus (0.07)
# Japanese_spaniel (0.06)
# Image 4927:
# clog (0.10)
# plate_rack (0.06)
# maraca (0.05)
# Image 4928:
# Windsor_tie (0.35)
# neck_brace (0.02)
# black-and-tan_coonhound (0.02)
# Image 4929:
# rock_beauty (0.32)
# Windsor_tie (0.07)
# plane (0.05)
# Image 4930:
# Egyptian_cat (0.14)
# tabby (0.12)
# Windsor_tie (0.09)
# Image 4931:
# Japanese_spaniel (0.11)
# Persian_cat (0.09)
# Siamese_cat (0.08)
# Image 4932:
# bearskin (0.34)
# bulletproof_vest (0.09)
# affenpinscher (0.04)
# Image 4933:
# chiffonier (0.13)
# fire_screen (0.13)
# dishwasher (0.09)
# Image 4934:
# Japanese_spaniel (0.08)
# Walker_hound (0.08)
# Eskimo_dog (0.06)
# Image 4935:
# moving_van (0.15)
# amphibian (0.12)
# container_ship (0.05)
# Image 4936:
# Windsor_tie (0.49)
# neck_brace (0.05)
# milk_can (0.04)
# Image 4937:
# tabby (0.27)
# toy_terrier (0.09)
# Windsor_tie (0.06)
# Image 4938:
# milk_can (0.38)
# can_opener (0.06)
# whiskey_jug (0.06)
# Image 4939:
# Windsor_tie (0.20)
# toy_terrier (0.10)
# fox_squirrel (0.07)
# Image 4940:
# Brabancon_griffon (0.11)
# Sussex_spaniel (0.10)
# redbone (0.07)
# Image 4941:
# waffle_iron (0.24)
# EntleBucher (0.22)
# can_opener (0.05)
# Image 4942:
# fox_squirrel (0.19)
# bluetick (0.05)
# German_short-haired_pointer (0.05)
# Image 4943:
# rock_beauty (0.12)
# polecat (0.06)
# Persian_cat (0.05)
# Image 4944:
# affenpinscher (0.50)
# Kerry_blue_terrier (0.09)
# Yorkshire_terrier (0.04)
# Image 4945:
# tabby (0.27)
# bathtub (0.08)
# fox_squirrel (0.04)
# Image 4946:
# pick (0.71)
# velvet (0.02)
# hair_slide (0.01)
# Image 4947:
# punching_bag (0.21)
# power_drill (0.09)
# oil_filter (0.06)
# Image 4948:
# affenpinscher (0.10)
# triceratops (0.05)
# dogsled (0.04)
# Image 4949:
# bearskin (0.17)
# pick (0.10)
# siamang (0.08)
# Image 4950:
# neck_brace (0.19)
# nipple (0.04)
# screen (0.03)
# Image 4951:
# tabby (0.13)
# Eskimo_dog (0.09)
# Egyptian_cat (0.07)
# Image 4952:
# kit_fox (0.17)
# brown_bear (0.09)
# fox_squirrel (0.07)
# Image 4953:
# muzzle (0.23)
# electric_ray (0.13)
# magnetic_compass (0.04)
# Image 4954:
# tabby (0.17)
# tiger_cat (0.05)
# triceratops (0.04)
# Image 4955:
# Japanese_spaniel (0.08)
# Persian_cat (0.04)
# nipple (0.02)
# Image 4956:
# kit_fox (0.23)
# grey_fox (0.19)
# red_wolf (0.13)
# Image 4957:
# letter_opener (0.09)
# harp (0.08)
# guillotine (0.07)
# Image 4958:
# eggnog (0.09)
# kit_fox (0.06)
# barn_spider (0.05)
# Image 4959:
# Egyptian_cat (0.50)
# tiger_cat (0.15)
# tabby (0.10)
# Image 4960:
# plate_rack (0.88)
# cradle (0.01)
# English_foxhound (0.01)
# Image 4961:
# crate (0.53)
# carton (0.27)
# dishwasher (0.02)
# Image 4962:
# Windsor_tie (0.20)
# platypus (0.04)
# vine_snake (0.03)
# Image 4963:
# tabby (0.21)
# tiger_cat (0.06)
# grey_fox (0.05)
# Image 4964:
# Mexican_hairless (0.26)
# Italian_greyhound (0.09)
# Siamese_cat (0.06)
# Image 4965:
# book_jacket (0.48)
# comic_book (0.11)
# jersey (0.09)
# Image 4966:
# bluetick (0.14)
# German_short-haired_pointer (0.11)
# Walker_hound (0.08)
# Image 4967:
# thresher (0.10)
# amphibian (0.10)
# container_ship (0.10)
# Image 4968:
# Brabancon_griffon (0.82)
# toy_terrier (0.11)
# redbone (0.01)
# Image 4969:
# coyote (0.13)
# fox_squirrel (0.09)
# wood_rabbit (0.07)
# Image 4970:
# screen (0.25)
# lion (0.25)
# Crock_Pot (0.03)
# Image 4971:
# Madagascar_cat (0.12)
# tabby (0.09)
# Siamese_cat (0.06)
# Image 4972:
# kit_fox (0.29)
# grey_fox (0.14)
# red_fox (0.08)
# Image 4973:
# Windsor_tie (0.16)
# toy_terrier (0.10)
# maraca (0.04)
# Image 4974:
# lesser_panda (0.64)
# red_fox (0.03)
# kit_fox (0.02)
# Image 4975:
# otterhound (0.21)
# Yorkshire_terrier (0.11)
# affenpinscher (0.05)
# Image 4976:
# English_foxhound (0.25)
# basset (0.14)
# Walker_hound (0.12)
# Image 4977:
# overskirt (0.09)
# punching_bag (0.07)
# bearskin (0.04)
# Image 4978:
# turnstile (0.11)
# guillotine (0.09)
# dining_table (0.08)
# Image 4979:
# tabby (0.80)
# tiger_cat (0.12)
# Egyptian_cat (0.04)
# Image 4980:
# Egyptian_cat (0.45)
# tabby (0.18)
# tiger_cat (0.04)
# Image 4981:
# bearskin (0.49)
# pickelhaube (0.11)
# mortarboard (0.09)
# Image 4982:
# Japanese_spaniel (0.66)
# Blenheim_spaniel (0.05)
# Persian_cat (0.03)
# Image 4983:
# coyote (0.14)
# Brabancon_griffon (0.06)
# marmoset (0.03)
# Image 4984:
# basenji (0.04)
# Egyptian_cat (0.04)
# milk_can (0.04)
# Image 4985:
# frilled_lizard (0.14)
# bluetick (0.12)
# triceratops (0.11)
# Image 4986:
# milk_can (0.81)
# whiskey_jug (0.02)
# barrel (0.01)
# Image 4987:
# otterhound (0.37)
# coyote (0.07)
# dhole (0.06)
# Image 4988:
# Egyptian_cat (0.60)
# tiger_cat (0.08)
# tabby (0.03)
# Image 4989:
# Egyptian_cat (0.26)
# snow_leopard (0.17)
# hyena (0.09)
# Image 4990:
# English_foxhound (0.10)
# bluetick (0.10)
# Walker_hound (0.10)
# Image 4991:
# Siamese_cat (0.98)
# indri (0.00)
# langur (0.00)
# Image 4992:
# redbone (0.21)
# golden_retriever (0.09)
# bloodhound (0.09)
# Image 4993:
# tiger (0.33)
# tiger_cat (0.16)
# bluetick (0.05)
# Image 4994:
# pickelhaube (0.08)
# waffle_iron (0.08)
# whiskey_jug (0.05)
# Image 4995:
# harp (0.13)
# can_opener (0.08)
# plane (0.07)
# Image 4996:
# table_lamp (0.11)
# whiskey_jug (0.11)
# drum (0.08)
# Image 4997:
# squirrel_monkey (0.20)
# Madagascar_cat (0.14)
# spider_monkey (0.09)
# Image 4998:
# desktop_computer (0.67)
# hand-held_computer (0.05)
# screen (0.03)
# Image 4999:
# tabby (0.28)
# Egyptian_cat (0.26)
# tiger_cat (0.07)
# Image 5000:
# can_opener (0.09)
# Windsor_tie (0.06)
# clog (0.02)

# %% [markdown]
# **9. Large-scale image recognition using transfer learning...**
#
# a. Make a training set of at least 100 images for each class. You might, for example, identify your
# own photos based on their position (beach, mountain, area, etc.) or use an existing dataset, such as
# the flowers dataset or MIT&#39;s places dataset (requires registration, and it is huge).
#
# b. Create a preprocessing phase that resizes and crops the image to 299 x 299 pixels while also
# adding some randomness for data augmentation.
#
# c. Using the previously trained Inception v3 model, freeze all layers up to the bottleneck layer (the
# last layer before output layer) and replace output layer with appropriate number of outputs for
# your new classification task (e.g., the flowers dataset has five mutually exclusive classes so the
# output layer must have five neurons and use softmax activation function).
#
# d. Separate the data into two sets: a training and a test set. The training set is used to train the
# model, and the test set is used to evaluate it.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# Step 1: Load the Flowers dataset
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    'tf_flowers',
    split=['train[:80%]', 'train[80%:90%]', 'train[90%:]'],
    with_info=True,
    as_supervised=True,
)

# Step 2: Preprocessing
IMG_SIZE = 299  # All images will be resized to 299x299

def format_example(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    # Data augmentation - Random flipping
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    # Normalize to [-1,1]
    image = (image / 127.5) - 1
    return image, label

train = raw_train.map(format_example)
validation = raw_validation.map(format_example)
test = raw_test.map(format_example)

# Batching and shuffling
BATCH_SIZE = 32
SHUFFLE_BUFFER_SIZE = 1000

train_batches = train.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
validation_batches = validation.batch(BATCH_SIZE)
test_batches = test.batch(BATCH_SIZE)

# Step 3: Transfer Learning with Inception v3
base_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet', input_shape=(IMG_SIZE, IMG_SIZE, 3))
base_model.trainable = False  # Freeze all layers of the base model

# Create new model on top
global_average_layer = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
prediction_layer = tf.keras.layers.Dense(metadata.features['label'].num_classes, activation='softmax')(global_average_layer)
model = tf.keras.models.Model(inputs=base_model.input, outputs=prediction_layer)

model.compile(optimizer=tf.keras.optimizers.Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_376 (Conv2D)         (None, 149, 149, 32)         864       ['input_5[0][0]']
#
#  batch_normalization_376 (B  (None, 149, 149, 32)         96        ['conv2d_376[0][0]']
#  atchNormalization)
#
#  activation_376 (Activation  (None, 149, 149, 32)         0         ['batch_normalization_376[0][0
#  )                                                                  ]']
#
#  conv2d_377 (Conv2D)         (None, 147, 147, 32)         9216      ['activation_376[0][0]']
#
#  batch_normalization_377 (B  (None, 147, 147, 32)         96        ['conv2d_377[0][0]']
#  atchNormalization)
#
#  activation_377 (Activation  (None, 147, 147, 32)         0         ['batch_normalization_377[0][0
#  )                                                                  ]']
#
#  conv2d_378 (Conv2D)         (None, 147, 147, 64)         18432     ['activation_377[0][0]']
#
#  batch_normalization_378 (B  (None, 147, 147, 64)         192       ['conv2d_378[0][0]']
#  atchNormalization)
#
#  activation_378 (Activation  (None, 147, 147, 64)         0         ['batch_normalization_378[0][0
#  )                                                                  ]']
#
#  max_pooling2d_16 (MaxPooli  (None, 73, 73, 64)           0         ['activation_378[0][0]']
#  ng2D)
#
#  conv2d_379 (Conv2D)         (None, 73, 73, 80)           5120      ['max_pooling2d_16[0][0]']
#
#  batch_normalization_379 (B  (None, 73, 73, 80)           240       ['conv2d_379[0][0]']
#  atchNormalization)
#
#  activation_379 (Activation  (None, 73, 73, 80)           0         ['batch_normalization_379[0][0
#  )                                                                  ]']
#
#  conv2d_380 (Conv2D)         (None, 71, 71, 192)          138240    ['activation_379[0][0]']
#
#  batch_normalization_380 (B  (None, 71, 71, 192)          576       ['conv2d_380[0][0]']
#  atchNormalization)
#
#  activation_380 (Activation  (None, 71, 71, 192)          0         ['batch_normalization_380[0][0
#  )                                                                  ]']
#
#  max_pooling2d_17 (MaxPooli  (None, 35, 35, 192)          0         ['activation_380[0][0]']
#  ng2D)
#
#  conv2d_384 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_17[0][0]']
#
#  batch_normalization_384 (B  (None, 35, 35, 64)           192       ['conv2d_384[0][0]']
#  atchNormalization)
#
#  activation_384 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_384[0][0
#  )                                                                  ]']
#
#  conv2d_382 (Conv2D)         (None, 35, 35, 48)           9216      ['max_pooling2d_17[0][0]']
#
#  conv2d_385 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_384[0][0]']
#
#  batch_normalization_382 (B  (None, 35, 35, 48)           144       ['conv2d_382[0][0]']
#  atchNormalization)
#
#  batch_normalization_385 (B  (None, 35, 35, 96)           288       ['conv2d_385[0][0]']
#  atchNormalization)
#
#  activation_382 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_382[0][0
#  )                                                                  ]']
#
#  activation_385 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_385[0][0
#  )                                                                  ]']
#
#  average_pooling2d_36 (Aver  (None, 35, 35, 192)          0         ['max_pooling2d_17[0][0]']
#  agePooling2D)
#
#  conv2d_381 (Conv2D)         (None, 35, 35, 64)           12288     ['max_pooling2d_17[0][0]']
#
#  conv2d_383 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)         (None, 35, 35, 32)           6144      ['average_pooling2d_36[0][0]']
#
#  batch_normalization_381 (B  (None, 35, 35, 64)           192       ['conv2d_381[0][0]']
#  atchNormalization)
#
#  batch_normalization_383 (B  (None, 35, 35, 64)           192       ['conv2d_383[0][0]']
#  atchNormalization)
#
#  batch_normalization_386 (B  (None, 35, 35, 96)           288       ['conv2d_386[0][0]']
#  atchNormalization)
#
#  batch_normalization_387 (B  (None, 35, 35, 32)           96        ['conv2d_387[0][0]']
#  atchNormalization)
#
#  activation_381 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_381[0][0
#  )                                                                  ]']
#
#  activation_383 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_383[0][0
#  )                                                                  ]']
#
#  activation_386 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_386[0][0
#  )                                                                  ]']
#
#  activation_387 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_387[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 35, 35, 256)          0         ['activation_381[0][0]',
#                                                                      'activation_383[0][0]',
#                                                                      'activation_386[0][0]',
#                                                                      'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_391 (B  (None, 35, 35, 64)           192       ['conv2d_391[0][0]']
#  atchNormalization)
#
#  activation_391 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_391[0][0
#  )                                                                  ]']
#
#  conv2d_389 (Conv2D)         (None, 35, 35, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_391[0][0]']
#
#  batch_normalization_389 (B  (None, 35, 35, 48)           144       ['conv2d_389[0][0]']
#  atchNormalization)
#
#  batch_normalization_392 (B  (None, 35, 35, 96)           288       ['conv2d_392[0][0]']
#  atchNormalization)
#
#  activation_389 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_389[0][0
#  )                                                                  ]']
#
#  activation_392 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_392[0][0
#  )                                                                  ]']
#
#  average_pooling2d_37 (Aver  (None, 35, 35, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_388 (Conv2D)         (None, 35, 35, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)         (None, 35, 35, 64)           16384     ['average_pooling2d_37[0][0]']
#
#  batch_normalization_388 (B  (None, 35, 35, 64)           192       ['conv2d_388[0][0]']
#  atchNormalization)
#
#  batch_normalization_390 (B  (None, 35, 35, 64)           192       ['conv2d_390[0][0]']
#  atchNormalization)
#
#  batch_normalization_393 (B  (None, 35, 35, 96)           288       ['conv2d_393[0][0]']
#  atchNormalization)
#
#  batch_normalization_394 (B  (None, 35, 35, 64)           192       ['conv2d_394[0][0]']
#  atchNormalization)
#
#  activation_388 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_388[0][0
#  )                                                                  ]']
#
#  activation_390 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_390[0][0
#  )                                                                  ]']
#
#  activation_393 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_393[0][0
#  )                                                                  ]']
#
#  activation_394 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_394[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 35, 35, 288)          0         ['activation_388[0][0]',
#                                                                      'activation_390[0][0]',
#                                                                      'activation_393[0][0]',
#                                                                      'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_398 (B  (None, 35, 35, 64)           192       ['conv2d_398[0][0]']
#  atchNormalization)
#
#  activation_398 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_398[0][0
#  )                                                                  ]']
#
#  conv2d_396 (Conv2D)         (None, 35, 35, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_398[0][0]']
#
#  batch_normalization_396 (B  (None, 35, 35, 48)           144       ['conv2d_396[0][0]']
#  atchNormalization)
#
#  batch_normalization_399 (B  (None, 35, 35, 96)           288       ['conv2d_399[0][0]']
#  atchNormalization)
#
#  activation_396 (Activation  (None, 35, 35, 48)           0         ['batch_normalization_396[0][0
#  )                                                                  ]']
#
#  activation_399 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_399[0][0
#  )                                                                  ]']
#
#  average_pooling2d_38 (Aver  (None, 35, 35, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_395 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)         (None, 35, 35, 64)           76800     ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)         (None, 35, 35, 96)           82944     ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)         (None, 35, 35, 64)           18432     ['average_pooling2d_38[0][0]']
#
#  batch_normalization_395 (B  (None, 35, 35, 64)           192       ['conv2d_395[0][0]']
#  atchNormalization)
#
#  batch_normalization_397 (B  (None, 35, 35, 64)           192       ['conv2d_397[0][0]']
#  atchNormalization)
#
#  batch_normalization_400 (B  (None, 35, 35, 96)           288       ['conv2d_400[0][0]']
#  atchNormalization)
#
#  batch_normalization_401 (B  (None, 35, 35, 64)           192       ['conv2d_401[0][0]']
#  atchNormalization)
#
#  activation_395 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_395[0][0
#  )                                                                  ]']
#
#  activation_397 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_397[0][0
#  )                                                                  ]']
#
#  activation_400 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_400[0][0
#  )                                                                  ]']
#
#  activation_401 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_401[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 35, 35, 288)          0         ['activation_395[0][0]',
#                                                                      'activation_397[0][0]',
#                                                                      'activation_400[0][0]',
#                                                                      'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)         (None, 35, 35, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_403 (B  (None, 35, 35, 64)           192       ['conv2d_403[0][0]']
#  atchNormalization)
#
#  activation_403 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_403[0][0
#  )                                                                  ]']
#
#  conv2d_404 (Conv2D)         (None, 35, 35, 96)           55296     ['activation_403[0][0]']
#
#  batch_normalization_404 (B  (None, 35, 35, 96)           288       ['conv2d_404[0][0]']
#  atchNormalization)
#
#  activation_404 (Activation  (None, 35, 35, 96)           0         ['batch_normalization_404[0][0
#  )                                                                  ]']
#
#  conv2d_402 (Conv2D)         (None, 17, 17, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)         (None, 17, 17, 96)           82944     ['activation_404[0][0]']
#
#  batch_normalization_402 (B  (None, 17, 17, 384)          1152      ['conv2d_402[0][0]']
#  atchNormalization)
#
#  batch_normalization_405 (B  (None, 17, 17, 96)           288       ['conv2d_405[0][0]']
#  atchNormalization)
#
#  activation_402 (Activation  (None, 17, 17, 384)          0         ['batch_normalization_402[0][0
#  )                                                                  ]']
#
#  activation_405 (Activation  (None, 17, 17, 96)           0         ['batch_normalization_405[0][0
#  )                                                                  ]']
#
#  max_pooling2d_18 (MaxPooli  (None, 17, 17, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 17, 17, 768)          0         ['activation_402[0][0]',
#                                                                      'activation_405[0][0]',
#                                                                      'max_pooling2d_18[0][0]']
#
#  conv2d_410 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_410 (B  (None, 17, 17, 128)          384       ['conv2d_410[0][0]']
#  atchNormalization)
#
#  activation_410 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  conv2d_411 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_410[0][0]']
#
#  batch_normalization_411 (B  (None, 17, 17, 128)          384       ['conv2d_411[0][0]']
#  atchNormalization)
#
#  activation_411 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  conv2d_407 (Conv2D)         (None, 17, 17, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_411[0][0]']
#
#  batch_normalization_407 (B  (None, 17, 17, 128)          384       ['conv2d_407[0][0]']
#  atchNormalization)
#
#  batch_normalization_412 (B  (None, 17, 17, 128)          384       ['conv2d_412[0][0]']
#  atchNormalization)
#
#  activation_407 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  activation_412 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_412[0][0
#  )                                                                  ]']
#
#  conv2d_408 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)         (None, 17, 17, 128)          114688    ['activation_412[0][0]']
#
#  batch_normalization_408 (B  (None, 17, 17, 128)          384       ['conv2d_408[0][0]']
#  atchNormalization)
#
#  batch_normalization_413 (B  (None, 17, 17, 128)          384       ['conv2d_413[0][0]']
#  atchNormalization)
#
#  activation_408 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  activation_413 (Activation  (None, 17, 17, 128)          0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  average_pooling2d_39 (Aver  (None, 17, 17, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_406 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)         (None, 17, 17, 192)          172032    ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_39[0][0]']
#
#  batch_normalization_406 (B  (None, 17, 17, 192)          576       ['conv2d_406[0][0]']
#  atchNormalization)
#
#  batch_normalization_409 (B  (None, 17, 17, 192)          576       ['conv2d_409[0][0]']
#  atchNormalization)
#
#  batch_normalization_414 (B  (None, 17, 17, 192)          576       ['conv2d_414[0][0]']
#  atchNormalization)
#
#  batch_normalization_415 (B  (None, 17, 17, 192)          576       ['conv2d_415[0][0]']
#  atchNormalization)
#
#  activation_406 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
#  activation_409 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_409[0][0
#  )                                                                  ]']
#
#  activation_414 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_414[0][0
#  )                                                                  ]']
#
#  activation_415 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_415[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 17, 17, 768)          0         ['activation_406[0][0]',
#                                                                      'activation_409[0][0]',
#                                                                      'activation_414[0][0]',
#                                                                      'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_420 (B  (None, 17, 17, 160)          480       ['conv2d_420[0][0]']
#  atchNormalization)
#
#  activation_420 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_420[0][0
#  )                                                                  ]']
#
#  conv2d_421 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_420[0][0]']
#
#  batch_normalization_421 (B  (None, 17, 17, 160)          480       ['conv2d_421[0][0]']
#  atchNormalization)
#
#  activation_421 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_421[0][0
#  )                                                                  ]']
#
#  conv2d_417 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_421[0][0]']
#
#  batch_normalization_417 (B  (None, 17, 17, 160)          480       ['conv2d_417[0][0]']
#  atchNormalization)
#
#  batch_normalization_422 (B  (None, 17, 17, 160)          480       ['conv2d_422[0][0]']
#  atchNormalization)
#
#  activation_417 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_417[0][0
#  )                                                                  ]']
#
#  activation_422 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_422[0][0
#  )                                                                  ]']
#
#  conv2d_418 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_422[0][0]']
#
#  batch_normalization_418 (B  (None, 17, 17, 160)          480       ['conv2d_418[0][0]']
#  atchNormalization)
#
#  batch_normalization_423 (B  (None, 17, 17, 160)          480       ['conv2d_423[0][0]']
#  atchNormalization)
#
#  activation_418 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_418[0][0
#  )                                                                  ]']
#  activation_423 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_423[0][0
#  )                                                                  ]']
#
#  average_pooling2d_40 (Aver  (None, 17, 17, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_416 (Conv2D)         (None, 17, 17, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)         (None, 17, 17, 192)          215040    ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)         (None, 17, 17, 192)          147456    ['average_pooling2d_40[0][0]']
#
#  batch_normalization_416 (B  (None, 17, 17, 192)          576       ['conv2d_416[0][0]']
#  atchNormalization)
#
#  batch_normalization_419 (B  (None, 17, 17, 192)          576       ['conv2d_419[0][0]']
#  atchNormalization)
#
#  batch_normalization_424 (B  (None, 17, 17, 192)          576       ['conv2d_424[0][0]']
#  atchNormalization)
#
#  batch_normalization_425 (B  (None, 17, 17, 192)          576       ['conv2d_425[0][0]']
#  atchNormalization)
#
#  activation_416 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_416[0][0
#  )                                                                  ]']
#
#  activation_419 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_419[0][0
#  )                                                                  ]']
#
#  activation_424 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_424[0][0
#  )                                                                  ]']
#
#  activation_425 (Activation  (None, 17, 17, 192)          0         ['batch_normalization_425[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 17, 17, 768)          0         ['activation_416[0][0]',
#                                                                      'activation_419[0][0]',
#                                                                      'activation_424[0][0]',
#                                                                      'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_430 (B  (None, 17, 17, 160)          480       ['conv2d_430[0][0]']
#  atchNormalization)
#
#  activation_430 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_430[0][0
#  )                                                                  ]']
#
#  conv2d_431 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_430[0][0]']
#
#  batch_normalization_431 (B  (None, 17, 17, 160)          480       ['conv2d_431[0][0]']
#  atchNormalization)
#
#  activation_431 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_431[0][0
#  )                                                                  ]']
#
#  conv2d_427 (Conv2D)         (None, 17, 17, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)         (None, 17, 17, 160)          179200    ['activation_431[0][0]']
#
#  batch_normalization_427 (B  (None, 17, 17, 160)          480       ['conv2d_427[0][0]']
#  atchNormalization)
#
#  batch_normalization_432 (B  (None, 17, 17, 160)          480       ['conv2d_432[0][0]']
#  atchNormalization)
#
#  activation_427 (Activation  (None, 17, 17, 160)          0         ['batch_normalization_427[0][0
#  )                                                                  ]']
# ...
#
#  activation_457 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_457[0][0
#  )                                                                  ]']
#
#  conv2d_454 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_457[0][0]']
#
#  average_pooling2d_43 (Aver  (None, 8, 8, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_452 (Conv2D)         (None, 8, 8, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_454 (B  (None, 8, 8, 384)            1152      ['conv2d_454[0][0]']
#  atchNormalization)
#
#  batch_normalization_455 (B  (None, 8, 8, 384)            1152      ['conv2d_455[0][0]']
#  atchNormalization)
#
#  batch_normalization_458 (B  (None, 8, 8, 384)            1152      ['conv2d_458[0][0]']
#  atchNormalization)
#
#  batch_normalization_459 (B  (None, 8, 8, 384)            1152      ['conv2d_459[0][0]']
#  atchNormalization)
#
#  conv2d_460 (Conv2D)         (None, 8, 8, 192)            245760    ['average_pooling2d_43[0][0]']
#
#  batch_normalization_452 (B  (None, 8, 8, 320)            960       ['conv2d_452[0][0]']
#  atchNormalization)
#
#  activation_454 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_454[0][0
#  )                                                                  ]']
#
#  activation_455 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_455[0][0
#  )                                                                  ]']
#
#  activation_458 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_458[0][0
#  )                                                                  ]']
#
#  activation_459 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_459[0][0
#  )                                                                  ]']
#
#  batch_normalization_460 (B  (None, 8, 8, 192)            576       ['conv2d_460[0][0]']
#  atchNormalization)
#
#  activation_452 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_452[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 8, 8, 768)            0         ['activation_454[0][0]',
#                                                                      'activation_455[0][0]']
#
#  concatenate_8 (Concatenate  (None, 8, 8, 768)            0         ['activation_458[0][0]',
#  )                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_460[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 8, 8, 2048)           0         ['activation_452[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_8[0][0]',
#                                                                      'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)         (None, 8, 8, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_465 (B  (None, 8, 8, 448)            1344      ['conv2d_465[0][0]']
#  atchNormalization)
#
#  activation_465 (Activation  (None, 8, 8, 448)            0         ['batch_normalization_465[0][0
#  )                                                                  ]']
#
#  conv2d_462 (Conv2D)         (None, 8, 8, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)         (None, 8, 8, 384)            1548288   ['activation_465[0][0]']
#
#  batch_normalization_462 (B  (None, 8, 8, 384)            1152      ['conv2d_462[0][0]']
#  atchNormalization)
#
#  batch_normalization_466 (B  (None, 8, 8, 384)            1152      ['conv2d_466[0][0]']
#  atchNormalization)
#
#  activation_462 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_462[0][0
#  )                                                                  ]']
#
#  activation_466 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_466[0][0
#  )                                                                  ]']
#
#  conv2d_463 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)         (None, 8, 8, 384)            442368    ['activation_466[0][0]']
#
#  average_pooling2d_44 (Aver  (None, 8, 8, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_461 (Conv2D)         (None, 8, 8, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_463 (B  (None, 8, 8, 384)            1152      ['conv2d_463[0][0]']
#  atchNormalization)
#
#  batch_normalization_464 (B  (None, 8, 8, 384)            1152      ['conv2d_464[0][0]']
#  atchNormalization)
#
#  batch_normalization_467 (B  (None, 8, 8, 384)            1152      ['conv2d_467[0][0]']
#  atchNormalization)
#
#  batch_normalization_468 (B  (None, 8, 8, 384)            1152      ['conv2d_468[0][0]']
#  atchNormalization)
#
#  conv2d_469 (Conv2D)         (None, 8, 8, 192)            393216    ['average_pooling2d_44[0][0]']
#
#  batch_normalization_461 (B  (None, 8, 8, 320)            960       ['conv2d_461[0][0]']
#  atchNormalization)
#
#  activation_463 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_463[0][0
#  )                                                                  ]']
#
#  activation_464 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_464[0][0
#  )                                                                  ]']
#
#  activation_467 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_467[0][0
#  )                                                                  ]']
#
#  activation_468 (Activation  (None, 8, 8, 384)            0         ['batch_normalization_468[0][0
#  )                                                                  ]']
#
#  batch_normalization_469 (B  (None, 8, 8, 192)            576       ['conv2d_469[0][0]']
#  atchNormalization)
#
#  activation_461 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_461[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 8, 8, 768)            0         ['activation_463[0][0]',
#                                                                      'activation_464[0][0]']
#
#  concatenate_9 (Concatenate  (None, 8, 8, 768)            0         ['activation_467[0][0]',
#  )                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_469[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 8, 8, 2048)           0         ['activation_461[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_9[0][0]',
#                                                                      'activation_469[0][0]']
#
#  global_average_pooling2d (  (None, 2048)                 0         ['mixed10[0][0]']
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 5)                    10245     ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 21813029 (83.21 MB)
# Trainable params: 10245 (40.02 KB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
# Train the model
history = model.fit(train_batches, epochs=5, validation_data=validation_batches)

# Evaluate on the test dataset
loss, accuracy = model.evaluate(test_batches)
print(f"Test accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/5
# 92/92 [==============================] - 141s 1s/step - loss: 0.7915 - accuracy: 0.7132 - val_loss: 0.4774 - val_accuracy: 0.8501
# Epoch 2/5
# 92/92 [==============================] - 250s 3s/step - loss: 0.4314 - accuracy: 0.8559 - val_loss: 0.3936 - val_accuracy: 0.8828
# Epoch 3/5
# 92/92 [==============================] - 237s 3s/step - loss: 0.3454 - accuracy: 0.8900 - val_loss: 0.3628 - val_accuracy: 0.8801
# Epoch 4/5
# 92/92 [==============================] - 238s 3s/step - loss: 0.3065 - accuracy: 0.9022 - val_loss: 0.3979 - val_accuracy: 0.8665
# Epoch 5/5
# 92/92 [==============================] - 235s 3s/step - loss: 0.2710 - accuracy: 0.9166 - val_loss: 0.3720 - val_accuracy: 0.8747
# 12/12 [==============================] - 24s 2s/step - loss: 0.2799 - accuracy: 0.9019
# Test accuracy: 90.19%
